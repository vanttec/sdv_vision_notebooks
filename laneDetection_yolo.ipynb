# %% [markdown]
# # Lane Detection with Yolov8 and OpenCV

# %% [markdown]
# Código para desplegar las líneas de un carril vehicular a partir de los resultados del modelo de Yolov8 de segmentación de tres clases: línea derecha, centro (carril), línea izquierda utilizando la función de transformada de líneas de Hough.

# %% [markdown]
# ## Importar Librerías
#
# Setting the environment of python and the files that we are goint to use in te proyect.
#
# Librerías:
# * OpenCV - 4.6.0
# * Numpy -
# * Matplotlib -
#
# Archivos:
# * Test Image: carril_seg.jpg
# * Test Video: carril_predict.mp4

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %% [markdown]
# ## Funciones para desplegar las líneas

# %% [markdown]
# **Dibujo de líneas en la imagen**

# %% [markdown]
# Original

# %%
def display_lines(image, lines):
    line_image = np.zeros_like(image)
    if lines is not None:
        for x1, y1, x2, y2 in lines:
            print("display_lines: ",(x1, y1, x2, y2))
            cv2.line(line_image, (x1, y1), (x2, y2), (255, 0, 0), 10)
    return line_image

# %% [markdown]
# Codigo perfeccionado

# %%
def display_lines(image, lines):
    line_image = np.zeros_like(image)
    if lines is not None:
        for x1, y1, x2, y2 in lines:
            print("display_lines: ",(x1, y1, x2, y2))
            cv2.line(line_image, (x1, y1), (x2, y2), (255, 0, 0), 10)
    return line_image

# %% [markdown]
# **Puntos para obtener una línea**

# %% [markdown]
# Original

# %%
def make_coordinates(image, line_parameters):
    # print(line_parameters)
    if np.isnan(line_parameters).any():
        print('No line parameters')
        return np.array([0, 0, 0, 0])
    else:
        slope, intercept = line_parameters
        y1 = image.shape[0]
        y2 = int(y1*(3/5))
        x1 = int((y1 - intercept)/slope)
        x2 = int((y2 - intercept)/slope)
        return np.array([x1, y1, x2, y2])

# %% [markdown]
# Perfeccionado

# %%
def make_coordinates(img_height, line_parameters):
    # print(line_parameters)
    if np.isnan(line_parameters).any():
        print('No line parameters')
        return np.array([0, 0, 0, 0])
    else:
        slope, intercept = line_parameters
        y1 = img_height
        y2 = int(y1*(3/5))
        x1 = int((y1 - intercept)/slope)
        x2 = int((y2 - intercept)/slope)
        if x1 > 10000 or x2 > 10000 or x1 < -10000 or x2 < -10000:
            return np.array([0, 0, 0, 0])
        return np.array([x1, y1, x2, y2])

# %% [markdown]
# **Puntos medios**

# %%
def center_pt(coordinates):    
    x = int((coordinates[0]+coordinates[2])/2)
    y = int((coordinates[1]+coordinates[3])/2)
    return np.array([x,y])

# %% [markdown]
# **Puntos medios - Dexter Lolo**

# %%
def center_pt(yPresent,yFuture,lines):
    x_coordinates = []
    cont = 0
    for line in lines:
        x1, y1, x2, y2 = line
        # Calculate slope
        if(x2==x1):
            m = 0.001
        else:
            m = (y2 - y1) / (x2 - x1)
        # Calculate x coordinate
        x = ((yPresent - y1) / m) + x1
        # print("I - slope and x - center pts",(m,x))
        x=int(x)
        x_coordinates.append(x)
        x = ((yFuture - y1) / m) + x1
        # print("II - slope and x - center pts",(m,x))
        x=int(x)
        x_coordinates.append(x)
        cont+=1
        print("Line- ",line)
    print("CONTADOR - ",cont)
    if ((x_coordinates[2]-x_coordinates[0])%2==0):
        xPm=int(x_coordinates[0]+((x_coordinates[2]-x_coordinates[0])/2))
    else:
        xPm=int(x_coordinates[0]+((x_coordinates[2]-x_coordinates[0]+1)/2))
    if ((x_coordinates[3]-x_coordinates[1])%2==0):
        xFm=int(x_coordinates[1]+((x_coordinates[3]-x_coordinates[1])/2))
    else:
        xFm=int(x_coordinates[1]+((x_coordinates[3]-x_coordinates[1]+1)/2))
    centerPoints=np.array([
        np.array([xPm, yPresent]),
        np.array([xFm, yFuture])
    ])
    print("Center Points", centerPoints)
    return(centerPoints)

# %% [markdown]
# **Display Center Points**

# %%
def makePoints(image, centers):
    circle_image = np.zeros_like(image)
    if centers is not None:
        for x, y in centers:
            cv2.circle(circle_image, (x,y),1, (255, 255, 255), 5)
    return circle_image

# %% [markdown]
# **Promedio de las líneas**

# %%
# def average_slope_intercept(image, lines):
def average_slope_intercept(lines):
    left_fit = []
    right_fit = []
    for line in lines:
        x1, y1, x2, y2 = line.reshape(4)
        parameters = np.polyfit((x1, x2), (y1, y2), 1)
        slope = parameters[0]
        intercept = parameters[1]
        if slope < 0:
            left_fit.append((slope, intercept))
        else:
            right_fit.append((slope, intercept))
    # Promedio
    left_fit_average = np.average(left_fit, axis=0)
    right_fit_average = np.average(right_fit, axis=0)
    # Mediana
    # left_fit_average = np.median(left_fit, axis=0)
    # right_fit_average = np.median(right_fit, axis=0)
    # left_line = make_coordinates(image, left_fit_average)
    # right_line = make_coordinates(image, right_fit_average)
    # # print("right",right_line)
    # # print("Lft",left_line)
    # pt_up = center_pt(np.array([left_line[2],left_line[3],right_line[2],right_line[3]]))
    # pt_low = center_pt(np.array([left_line[0],left_line[1],right_line[0],right_line[1]]))
    # print("UP",pt_up)
    # print("LOW",pt_low)
    # return np.array([left_line, right_line])
    return np.array([left_fit_average, right_fit_average])

# %% [markdown]
# ### Original

# %%
def average_slope_intercept(img_height, lines):
    left_fit = []
    right_fit = []
    for line in lines:
        x1, y1, x2, y2 = line.reshape(4)
        parameters = np.polyfit((x1, x2), (y1, y2), 1)
        slope = parameters[0]
        intercept = parameters[1]
        if slope < 0:
            # print("SI - Left",(slope, intercept))
            left_fit.append((slope, intercept))
        else:
            # print("SI - Right",(slope, intercept))
            right_fit.append((slope, intercept))
    # Promedio
    left_fit_average = np.average(left_fit, axis=0)
    right_fit_average = np.average(right_fit, axis=0)
    # Mediana
    # left_fit_average = np.median(left_fit, axis=0)
    # right_fit_average = np.median(right_fit, axis=0)
    print("Left line average",left_fit_average)
    print("Right line average",right_fit_average)
    left_line = make_coordinates(img_height, left_fit_average)
    right_line = make_coordinates(img_height, right_fit_average)
    return np.array([left_line, right_line])

# %% [markdown]
# ## Despliege de los resultados en video - total

# %%
model = YOLO("./Yolov8/weights/best_feb2024_FINSA.pt")  # segmentation model
names = model.model.names

# %% [markdown]
# **Código para pruebas - se despliegan los resultados de la segmentación en imagen binaria**

# %%
model = YOLO("./Yolov8/weights_feb2024/best.pt")  # segmentation model
cap = cv2.VideoCapture("./Yolov8/carril.mp4")
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

out = cv2.VideoWriter('instance-segmentation-new-model.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))
out_bin = cv2.VideoWriter('instance-segmentation-binary-new-model.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))

names = model.model.names
while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    results = model.predict(im0)
    height,width = im0.shape[:2]
    polylines_im = np.zeros((height,width, 1), np.uint8)
    averaged_lines_left = []
    averaged_lines_right = []
    if results[0].masks is not None:
        clss = results[0].boxes.cls.cpu().tolist()
        masks = results[0].masks.xy
        for mask, cls in zip(masks, clss):
            if mask is not None and names[int(cls)] == "center":
                cv2.polylines(polylines_im, [np.int32(mask)], isClosed=False, color=255, thickness=5)
                cv2.polylines(im0, [np.int32(mask)], isClosed=False, color=(255,255,0), thickness=5)
    polylines_im = cv2.medianBlur(polylines_im, 7)
    height,width = polylines_im.shape[:2]
    polylines_im[height-200:height, 0:width] = 0
    cv2.imshow("binary", polylines_im)
    lines = cv2.HoughLinesP(polylines_im, 5, np.pi/180, 100, np.array([]), minLineLength=100, maxLineGap=10)
    if lines is not None:
        averaged_lines= average_slope_intercept(lines)
        print("avarage Left", averaged_lines[0])
        averaged_lines_left.append(averaged_lines[0])
        averaged_lines_right.append(averaged_lines[1])
        if averaged_lines[0] is None:
            averaged_lines_left.pop()
            averaged_lines[0] = averaged_lines_left[len(averaged_lines_left)-1]
        if averaged_lines[1] is None:
            averaged_lines_right.pop()
            averaged_lines[1] = averaged_lines_right[len(averaged_lines_right)-1]
        # Crear coordenadas de las futuras líneas
        left_line = make_coordinates(im0, averaged_lines[0])
        right_line = make_coordinates(im0, averaged_lines[1])
        line_image = display_lines(im0, np.array([left_line,right_line]))
        im0 = cv2.addWeighted(im0, 0.8, line_image, 1, 1)
        
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(im0, (x1, y1), (x2, y2), (0, 255, 0), 2)

    out.write(im0)
    out_bin.write(polylines_im)
    cv2.imshow("instance-segmentation", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

out.release()
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# **Video con Dexter Lolo**

# %%
cap = cv2.VideoCapture('./Yolov8/carril.mp4')
# w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
# out = cv2.VideoWriter('segmentacion-feb2024.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))
counter = 0 
flag = True
while(cap.isOpened()):
    counter +=1
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    # Se realiza una copya a escala de grises de la imagen original para visualizar los resultados de forma más rápida
    im0_gray = np.copy(im0)
    im0_gray = cv2.cvtColor(im0_gray, cv2.COLOR_BGR2GRAY)
    
    # Se realiza la predicción de la imagen
    results = model.predict(im0)
    # Se crea una imagen binaria para visualizar las máscaras
    height,width = im0.shape[:2]
    polylines_im = np.zeros((height,width, 1), np.uint8)
    
    if results[0].masks is not None:
        clss = results[0].boxes.cls.cpu().tolist()
        masks = results[0].masks.xy
        for mask, cls in zip(masks, clss):
            if mask is not None and names[int(cls)] == "center":
                cv2.polylines(polylines_im, [np.int32(mask)], isClosed=True, color=255, thickness=5)
                # cv2.polylines(im0, [np.int32(mask)], isClosed=False, color=(255,255,0), thickness=5)
        # polylines_im = cv2.medianBlur(polylines_im, 7)
        # height,width = polylines_im.shape[:2]
        polylines_im[height-205:height, 0:width] = 0
        polylines_im[0:450, 0:width] = 0
        cv2.imshow("binary", polylines_im)
        lines = cv2.HoughLinesP(polylines_im, 5, np.pi/180, 100, np.array([]), minLineLength=100, maxLineGap=10)
        if lines is not None:
            averaged_lines = average_slope_intercept(height, lines)
            print("AVERAGED LINES", averaged_lines)
            if not np.isnan(averaged_lines).any():
                line_image = display_lines(im0_gray, averaged_lines)
                center_points = center_pt(500,680,averaged_lines)
                combo_image = cv2.addWeighted(im0_gray, 0.8, line_image, 1, 1)
                center_point_image=makePoints(combo_image,center_points)
                combo_combo_image=cv2.addWeighted(combo_image, 0.8, center_point_image, 1, 1)
            else:
                print("No line parameters", averaged_lines)
        if counter%2 == 0:    
            cv2.imshow('result',combo_combo_image)

    # out.write(combo_combo_image)
    if cv2.waitKey(1) == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# Version Jetson

# %%
cap = cv2.VideoCapture('./Yolov8/carril.mp4')
# w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
# out = cv2.VideoWriter('segmentacion-feb2024.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))
counter = 0 
flag = True
while(cap.isOpened()):
    counter +=1
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    # Se realiza una copya a escala de grises de la imagen original para visualizar los resultados de forma más rápida
    im0_gray = np.copy(im0)
    im0_gray = cv2.cvtColor(im0_gray, cv2.COLOR_BGR2GRAY)
    combo_combo_image = im0_gray
    
    # Se crea una imagen binaria para visualizar las máscaras
    height,width = im0.shape[:2]
    polylines_im = np.zeros((height,width, 1), np.uint8)
    
    # Se realiza la predicción de la imagen
    results = model.predict(im0)
    if counter%2 == 0:    
        if results[0].masks is not None:
            clss = results[0].boxes.cls.cpu().tolist()
            masks = results[0].masks.xy
            for mask, cls in zip(masks, clss):
                if mask is not None and names[int(cls)] == "center":
                    cv2.polylines(polylines_im, [np.int32(mask)], isClosed=True, color=255, thickness=5)
            polylines_im[height-205:height, 0:width] = 0
            polylines_im[0:450, 0:width] = 0
            cv2.imshow("binary", polylines_im)
            lines = cv2.HoughLinesP(polylines_im, 5, np.pi/180, 100, np.array([]), minLineLength=100, maxLineGap=10)
            if lines is not None:
                averaged_lines = average_slope_intercept(height, lines)
                print("AVERAGED LINES", averaged_lines)
                if not np.isnan(averaged_lines).any():
                    # line_image = display_lines(im0_gray, averaged_lines)
                    center_points = center_pt(500,680,averaged_lines)
                    for x1, y1, x2, y2 in averaged_lines:
                        print("display_lines: ",(x1, y1, x2, y2))
                        cv2.line(im0_gray, (x1, y1), (x2, y2), (255, 0, 0), 10)
                    for x, y in center_points:
                        cv2.circle(im0_gray, (x,y),1, (255, 0, 0), 5)
                    # combo_image = cv2.addWeighted(im0_gray, 0.8, line_image, 1, 1)
                    # center_point_image=makePoints(combo_image,center_points)
                    # combo_combo_image=cv2.addWeighted(combo_image, 0.8, center_point_image, 1, 1)
    cv2.imshow('result',im0_gray)

    # out.write(combo_combo_image)
    if cv2.waitKey(1) == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 83.8ms
# Speed: 4.0ms preprocess, 83.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 48.9ms
# Speed: 3.0ms preprocess, 48.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36985       652.4]
# Right line average [    0.32036      226.27]
# AVERAGED LINES [[-182  720  595  432]
#  [1541  720  642  432]]
# Line-  [-182  720  595  432]
# Line-  [1541  720  642  432]
# CONTADOR -  2
# Center Points [[633 500]
#  [671 680]]
# display_lines:  (-182, 720, 595, 432)
# display_lines:  (1541, 720, 642, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 48.9ms
# Speed: 3.0ms preprocess, 48.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34722       640.9]
# Right line average [    0.32179      225.71]
# AVERAGED LINES [[-227  720  601  432]
#  [1536  720  641  432]]
# Line-  [-227  720  601  432]
# Line-  [1536  720  641  432]
# CONTADOR -  2
# Center Points [[629 500]
#  [650 680]]
# display_lines:  (-227, 720, 601, 432)
# display_lines:  (1536, 720, 641, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35205      642.85]
# Right line average [    0.32977      222.53]
# AVERAGED LINES [[-219  720  598  432]
#  [1508  720  635  432]]
# Line-  [-219  720  598  432]
# Line-  [1508  720  635  432]
# CONTADOR -  2
# Center Points [[623 500]
#  [641 680]]
# display_lines:  (-219, 720, 598, 432)
# display_lines:  (1508, 720, 635, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36504      647.35]
# Right line average [     0.3076         242]
# AVERAGED LINES [[-199  720  589  432]
#  [1553  720  617  432]]
# Line-  [-199  720  589  432]
# Line-  [1553  720  617  432]
# CONTADOR -  2
# Center Points [[620 500]
#  [667 680]]
# display_lines:  (-199, 720, 589, 432)
# display_lines:  (1553, 720, 617, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3558      643.25]
# Right line average [    0.30691      242.62]
# AVERAGED LINES [[-215  720  593  432]
#  [1555  720  617  432]]
# Line-  [-215  720  593  432]
# Line-  [1555  720  617  432]
# CONTADOR -  2
# Center Points [[620 500]
#  [661 680]]
# display_lines:  (-215, 720, 593, 432)
# display_lines:  (1555, 720, 617, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35686      643.78]
# Right line average [    0.32774      227.91]
# AVERAGED LINES [[-213  720  593  432]
#  [1501  720  622  432]]
# Line-  [-213  720  593  432]
# Line-  [1501  720  622  432]
# CONTADOR -  2
# Center Points [[616 500]
#  [639 680]]
# display_lines:  (-213, 720, 593, 432)
# display_lines:  (1501, 720, 622, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.33291      630.66]
# Right line average [    0.32674       230.7]
# AVERAGED LINES [[-268  720  596  432]
#  [1497  720  616  432]]
# Line-  [-268  720  596  432]
# Line-  [1497  720  616  432]
# CONTADOR -  2
# Center Points [[608 500]
#  [613 680]]
# display_lines:  (-268, 720, 596, 432)
# display_lines:  (1497, 720, 616, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34723      638.01]
# Right line average [    0.29741      249.53]
# AVERAGED LINES [[-236  720  593  432]
#  [1581  720  613  432]]
# Line-  [-236  720  593  432]
# Line-  [1581  720  613  432]
# CONTADOR -  2
# Center Points [[619 500]
#  [663 680]]
# display_lines:  (-236, 720, 593, 432)
# display_lines:  (1581, 720, 613, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36254      646.93]
# Right line average [    0.29659      252.95]
# AVERAGED LINES [[-201  720  592  432]
#  [1574  720  603  432]]
# Line-  [-201  720  592  432]
# Line-  [1574  720  603  432]
# CONTADOR -  2
# Center Points [[618 500]
#  [675 680]]
# display_lines:  (-201, 720, 592, 432)
# display_lines:  (1574, 720, 603, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3584      645.03]
# Right line average [    0.29174      256.15]
# AVERAGED LINES [[-209  720  594  432]
#  [1589  720  602  432]]
# Line-  [-209  720  594  432]
# Line-  [1589  720  602  432]
# CONTADOR -  2
# Center Points [[620 500]
#  [677 680]]
# display_lines:  (-209, 720, 594, 432)
# display_lines:  (1589, 720, 602, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35309      642.28]
# Right line average [    0.31681      238.97]
# AVERAGED LINES [[-220  720  595  432]
#  [1518  720  609  432]]
# Line-  [-220  720  595  432]
# Line-  [1518  720  609  432]
# CONTADOR -  2
# Center Points [[613 500]
#  [643 680]]
# display_lines:  (-220, 720, 595, 432)
# display_lines:  (1518, 720, 609, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37585      648.48]
# Right line average [    0.32102      235.66]
# AVERAGED LINES [[-190  720  575  432]
#  [1508  720  611  432]]
# Line-  [-190  720  575  432]
# Line-  [1508  720  611  432]
# CONTADOR -  2
# Center Points [[608 500]
#  [650 680]]
# display_lines:  (-190, 720, 575, 432)
# display_lines:  (1508, 720, 611, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36993      644.29]
# Right line average [     0.2909      263.08]
# AVERAGED LINES [[-204  720  573  432]
#  [1570  720  580  432]]
# Line-  [-204  720  573  432]
# Line-  [1570  720  580  432]
# CONTADOR -  2
# Center Points [[601 500]
#  [668 680]]
# display_lines:  (-204, 720, 573, 432)
# display_lines:  (1570, 720, 580, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35464      631.83]
# Right line average [     0.2927      261.29]
# AVERAGED LINES [[-248  720  563  432]
#  [1567  720  583  432]]
# Line-  [-248  720  563  432]
# Line-  [1567  720  583  432]
# CONTADOR -  2
# Center Points [[593 500]
#  [648 680]]
# display_lines:  (-248, 720, 563, 432)
# display_lines:  (1567, 720, 583, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37673      641.96]
# Right line average [    0.29394       260.4]
# AVERAGED LINES [[-207  720  557  432]
#  [1563  720  583  432]]
# Line-  [-207  720  557  432]
# Line-  [1563  720  583  432]
# CONTADOR -  2
# Center Points [[595 500]
#  [663 680]]
# display_lines:  (-207, 720, 557, 432)
# display_lines:  (1563, 720, 583, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3763      646.76]
# Right line average [    0.30984      246.62]
# AVERAGED LINES [[-194  720  570  432]
#  [1527  720  598  432]]
# Line-  [-194  720  570  432]
# Line-  [1527  720  598  432]
# CONTADOR -  2
# Center Points [[603 500]
#  [655 680]]
# display_lines:  (-194, 720, 570, 432)
# display_lines:  (1527, 720, 598, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36279      640.87]
# Right line average [     0.3073       247.1]
# AVERAGED LINES [[-218  720  575  432]
#  [1538  720  601  432]]
# Line-  [-218  720  575  432]
# Line-  [1538  720  601  432]
# CONTADOR -  2
# Center Points [[605 500]
#  [650 680]]
# display_lines:  (-218, 720, 575, 432)
# display_lines:  (1538, 720, 601, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3528      638.63]
# Right line average [    0.32155      235.83]
# AVERAGED LINES [[-230  720  585  432]
#  [1505  720  610  432]]
# Line-  [-230  720  585  432]
# Line-  [1505  720  610  432]
# CONTADOR -  2
# Center Points [[607 500]
#  [632 680]]
# display_lines:  (-230, 720, 585, 432)
# display_lines:  (1505, 720, 610, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3528      638.63]
# Right line average [    0.32155      235.83]
# AVERAGED LINES [[-230  720  585  432]
#  [1505  720  610  432]]
# Line-  [-230  720  585  432]
# Line-  [1505  720  610  432]
# CONTADOR -  2
# Center Points [[607 500]
#  [632 680]]
# display_lines:  (-230, 720, 585, 432)
# display_lines:  (1505, 720, 610, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35989      640.08]
# Right line average [    0.30398      248.03]
# AVERAGED LINES [[-222  720  578  432]
#  [1552  720  605  432]]
# Line-  [-222  720  578  432]
# Line-  [1552  720  605  432]
# CONTADOR -  2
# Center Points [[609 500]
#  [655 680]]
# display_lines:  (-222, 720, 578, 432)
# display_lines:  (1552, 720, 605, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3659      642.37]
# Right line average [    0.29633      254.47]
# AVERAGED LINES [[-212  720  574  432]
#  [1570  720  599  432]]
# Line-  [-212  720  574  432]
# Line-  [1570  720  599  432]
# CONTADOR -  2
# Center Points [[608 500]
#  [667 680]]
# display_lines:  (-212, 720, 574, 432)
# display_lines:  (1570, 720, 599, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36628      647.58]
# Right line average [    0.29213      257.05]
# AVERAGED LINES [[-197  720  588  432]
#  [1584  720  598  432]]
# Line-  [-197  720  588  432]
# Line-  [1584  720  598  432]
# CONTADOR -  2
# Center Points [[616 500]
#  [680 680]]
# display_lines:  (-197, 720, 588, 432)
# display_lines:  (1584, 720, 598, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35285      636.81]
# Right line average [    0.28983      259.97]
# AVERAGED LINES [[-235  720  580  432]
#  [1587  720  593  432]]
# Line-  [-235  720  580  432]
# Line-  [1587  720  593  432]
# CONTADOR -  2
# Center Points [[607 500]
#  [664 680]]
# display_lines:  (-235, 720, 580, 432)
# display_lines:  (1587, 720, 593, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 3 line_rights, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35351      631.28]
# Right line average [    0.34043      215.45]
# AVERAGED LINES [[-250  720  563  432]
#  [1482  720  636  432]]
# Line-  [-250  720  563  432]
# Line-  [1482  720  636  432]
# CONTADOR -  2
# Center Points [[603 500]
#  [614 680]]
# display_lines:  (-250, 720, 563, 432)
# display_lines:  (1482, 720, 636, 432)
#
# 0: 384x640 1 center, 1 line_left, 3 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 3 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35351      631.28]
# Right line average [    0.34043      215.45]
# AVERAGED LINES [[-250  720  563  432]
#  [1482  720  636  432]]
# Line-  [-250  720  563  432]
# Line-  [1482  720  636  432]
# CONTADOR -  2
# Center Points [[603 500]
#  [614 680]]
# display_lines:  (-250, 720, 563, 432)
# display_lines:  (1482, 720, 636, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3668      647.34]
# Right line average [    0.41985      155.87]
# AVERAGED LINES [[-198  720  587  432]
#  [1343  720  657  432]]
# Line-  [-198  720  587  432]
# Line-  [1343  720  657  432]
# CONTADOR -  2
# Center Points [[610 500]
#  [580 680]]
# display_lines:  (-198, 720, 587, 432)
# display_lines:  (1343, 720, 657, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37309      652.02]
# Right line average [    0.33915      226.48]
# AVERAGED LINES [[-182  720  589  432]
#  [1455  720  605  432]]
# Line-  [-182  720  589  432]
# Line-  [1455  720  605  432]
# CONTADOR -  2
# Center Points [[606 500]
#  [631 680]]
# display_lines:  (-182, 720, 589, 432)
# display_lines:  (1455, 720, 605, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37831      660.16]
# Right line average [    0.30754      251.35]
# AVERAGED LINES [[-158  720  603  432]
#  [1523  720  587  432]]
# Line-  [-158  720  603  432]
# Line-  [1523  720  587  432]
# CONTADOR -  2
# Center Points [[616 500]
#  [671 680]]
# display_lines:  (-158, 720, 603, 432)
# display_lines:  (1523, 720, 587, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35227      648.21]
# Right line average [    0.31703      244.74]
# AVERAGED LINES [[-203  720  613  432]
#  [1499  720  590  432]]
# Line-  [-203  720  613  432]
# Line-  [1499  720  590  432]
# CONTADOR -  2
# Center Points [[612 500]
#  [642 680]]
# display_lines:  (-203, 720, 613, 432)
# display_lines:  (1499, 720, 590, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34911      641.03]
# Right line average [    0.30453      249.16]
# AVERAGED LINES [[-226  720  598  432]
#  [1546  720  600  432]]
# Line-  [-226  720  598  432]
# Line-  [1546  720  600  432]
# CONTADOR -  2
# Center Points [[613 500]
#  [652 680]]
# display_lines:  (-226, 720, 598, 432)
# display_lines:  (1546, 720, 600, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36121      644.57]
# Right line average [     0.3283      225.63]
# AVERAGED LINES [[-208  720  588  432]
#  [1505  720  628  432]]
# Line-  [-208  720  588  432]
# Line-  [1505  720  628  432]
# CONTADOR -  2
# Center Points [[618 500]
#  [643 680]]
# display_lines:  (-208, 720, 588, 432)
# display_lines:  (1505, 720, 628, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35233      643.59]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-216  720  600  432]
#  [   0    0    0    0]]
# Line-  [-216  720  600  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250204    500]
#  [339949    680]]
# display_lines:  (-216, 720, 600, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35323      644.37]
# Right line average [    0.27809      265.19]
# AVERAGED LINES [[-214  720  601  432]
#  [1635  720  599  432]]
# Line-  [-214  720  601  432]
# Line-  [1635  720  599  432]
# CONTADOR -  2
# Center Points [[626 500]
#  [696 680]]
# display_lines:  (-214, 720, 601, 432)
# display_lines:  (1635, 720, 599, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37796      655.54]
# Right line average [    0.27621      266.61]
# AVERAGED LINES [[-170  720  591  432]
#  [1641  720  598  432]]
# Line-  [-170  720  591  432]
# Line-  [1641  720  598  432]
# CONTADOR -  2
# Center Points [[628 500]
#  [716 680]]
# display_lines:  (-170, 720, 591, 432)
# display_lines:  (1641, 720, 598, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 19.9ms
# c:\Users\frida\.conda\envs\yolo_new\Lib\site-packages\numpy\lib\function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# c:\Users\frida\.conda\envs\yolo_new\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Speed: 3.0ms preprocess, 19.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [     -0.358       650.5]
# Right line average [    0.31965      233.05]
# AVERAGED LINES [[-194  720  610  432]
#  [1523  720  622  432]]
# Line-  [-194  720  610  432]
# Line-  [1523  720  622  432]
# CONTADOR -  2
# Center Points [[627 500]
#  [658 680]]
# display_lines:  (-194, 720, 610, 432)
# display_lines:  (1523, 720, 622, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 19.0ms
# Speed: 3.0ms preprocess, 19.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.33146      637.76]
# Right line average [    0.35002      214.59]
# AVERAGED LINES [[-248  720  620  432]
#  [1443  720  621  432]]
# Line-  [-248  720  620  432]
# Line-  [1443  720  621  432]
# CONTADOR -  2
# Center Points [[615 500]
#  [601 680]]
# display_lines:  (-248, 720, 620, 432)
# display_lines:  (1443, 720, 621, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 28.9ms
# Speed: 3.0ms preprocess, 28.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3423      645.26]
# Right line average [    0.31796      242.88]
# AVERAGED LINES [[-218  720  623  432]
#  [1500  720  594  432]]
# Line-  [-218  720  623  432]
# Line-  [1500  720  594  432]
# CONTADOR -  2
# Center Points [[616 500]
#  [637 680]]
# display_lines:  (-218, 720, 623, 432)
# display_lines:  (1500, 720, 594, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.32334      629.53]
# Right line average [    0.33361      231.81]
# AVERAGED LINES [[-279  720  610  432]
#  [1463  720  600  432]]
# Line-  [-279  720  610  432]
# Line-  [1463  720  600  432]
# CONTADOR -  2
# Center Points [[602 500]
#  [594 680]]
# display_lines:  (-279, 720, 610, 432)
# display_lines:  (1463, 720, 600, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.38621      658.47]
# Right line average [    0.33871      230.04]
# AVERAGED LINES [[-159  720  586  432]
#  [1446  720  596  432]]
# Line-  [-159  720  586  432]
# Line-  [1446  720  596  432]
# CONTADOR -  2
# Center Points [[603 500]
#  [636 680]]
# display_lines:  (-159, 720, 586, 432)
# display_lines:  (1446, 720, 596, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.38564      653.43]
# Right line average [     0.4169      171.66]
# AVERAGED LINES [[-172  720  574  432]
#  [1315  720  624  432]]
# Line-  [-172  720  574  432]
# Line-  [1315  720  624  432]
# CONTADOR -  2
# Center Points [[592 500]
#  [576 680]]
# display_lines:  (-172, 720, 574, 432)
# display_lines:  (1315, 720, 624, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.40779      668.93]
# Right line average [    0.42499       160.3]
# AVERAGED LINES [[-125  720  581  432]
#  [1316  720  639  432]]
# Line-  [-125  720  581  432]
# Line-  [1316  720  639  432]
# CONTADOR -  2
# Center Points [[606 500]
#  [598 680]]
# display_lines:  (-125, 720, 581, 432)
# display_lines:  (1316, 720, 639, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.33277      630.29]
# Right line average [    0.44537      154.56]
# AVERAGED LINES [[-269  720  595  432]
#  [1269  720  622  432]]
# Line-  [-269  720  595  432]
# Line-  [1269  720  622  432]
# CONTADOR -  2
# Center Points [[583 500]
#  [515 680]]
# display_lines:  (-269, 720, 595, 432)
# display_lines:  (1269, 720, 622, 432)
#
# 0: 384x640 1 center, 1 line_left, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36845      646.07]
# Right line average [    0.40526      184.75]
# AVERAGED LINES [[-200  720  581  432]
#  [1320  720  610  432]]
# Line-  [-200  720  581  432]
# Line-  [1320  720  610  432]
# CONTADOR -  2
# Center Points [[587 500]
#  [565 680]]
# display_lines:  (-200, 720, 581, 432)
# display_lines:  (1320, 720, 610, 432)
#
# 0: 384x640 1 center, 1 line_left, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3709      650.68]
# Right line average [    0.47664      129.86]
# AVERAGED LINES [[-186  720  589  432]
#  [1238  720  633  432]]
# Line-  [-186  720  589  432]
# Line-  [1238  720  633  432]
# CONTADOR -  2
# Center Points [[591 500]
#  [538 680]]
# display_lines:  (-186, 720, 589, 432)
# display_lines:  (1238, 720, 633, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36162      646.24]
# Right line average [     0.4584      145.32]
# AVERAGED LINES [[-203  720  592  432]
#  [1253  720  625  432]]
# Line-  [-203  720  592  432]
# Line-  [1253  720  625  432]
# CONTADOR -  2
# Center Points [[589 500]
#  [537 680]]
# display_lines:  (-203, 720, 592, 432)
# display_lines:  (1253, 720, 625, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34202      634.91]
# Right line average [    0.47718      131.55]
# AVERAGED LINES [[-248  720  593  432]
#  [1233  720  629  432]]
# Line-  [-248  720  593  432]
# Line-  [1233  720  629  432]
# CONTADOR -  2
# Center Points [[583 500]
#  [509 680]]
# display_lines:  (-248, 720, 593, 432)
# display_lines:  (1233, 720, 629, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34415      634.17]
# Right line average [    0.47151      136.15]
# AVERAGED LINES [[-249  720  587  432]
#  [1238  720  627  432]]
# Line-  [-249  720  587  432]
# Line-  [1238  720  627  432]
# CONTADOR -  2
# Center Points [[580 500]
#  [511 680]]
# display_lines:  (-249, 720, 587, 432)
# display_lines:  (1238, 720, 627, 432)
#
# 0: 384x640 1 center, 1 line_left, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36777      647.26]
# Right line average [    0.46465      140.99]
# AVERAGED LINES [[-197  720  585  432]
#  [1246  720  626  432]]
# Line-  [-197  720  585  432]
# Line-  [1246  720  626  432]
# CONTADOR -  2
# Center Points [[586 500]
#  [536 680]]
# display_lines:  (-197, 720, 585, 432)
# display_lines:  (1246, 720, 626, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36779      648.48]
# Right line average [    0.42645      168.53]
# AVERAGED LINES [[-194  720  588  432]
#  [1293  720  617  432]]
# Line-  [-194  720  588  432]
# Line-  [1293  720  617  432]
# CONTADOR -  2
# Center Points [[590 500]
#  [557 680]]
# display_lines:  (-194, 720, 588, 432)
# display_lines:  (1293, 720, 617, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.33834      633.97]
# Right line average [    0.42745      164.87]
# AVERAGED LINES [[-254  720  596  432]
#  [1298  720  624  432]]
# Line-  [-254  720  596  432]
# Line-  [1298  720  624  432]
# CONTADOR -  2
# Center Points [[589 500]
#  [535 680]]
# display_lines:  (-254, 720, 596, 432)
# display_lines:  (1298, 720, 624, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36587      642.05]
# Right line average [    0.41054      181.84]
# AVERAGED LINES [[-213  720  574  432]
#  [1310  720  609  432]]
# Line-  [-213  720  574  432]
# Line-  [1310  720  609  432]
# CONTADOR -  2
# Center Points [[581 500]
#  [555 680]]
# display_lines:  (-213, 720, 574, 432)
# display_lines:  (1310, 720, 609, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.33715      633.16]
# Right line average [    0.45239      146.26]
# AVERAGED LINES [[-257  720  596  432]
#  [1268  720  631  432]]
# Line-  [-257  720  596  432]
# Line-  [1268  720  631  432]
# CONTADOR -  2
# Center Points [[588 500]
#  [521 680]]
# display_lines:  (-257, 720, 596, 432)
# display_lines:  (1268, 720, 631, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.33752      633.73]
# Right line average [    0.47133      131.36]
# AVERAGED LINES [[-255  720  597  432]
#  [1248  720  637  432]]
# Line-  [-255  720  597  432]
# Line-  [1248  720  637  432]
# CONTADOR -  2
# Center Points [[588 500]
#  [514 680]]
# display_lines:  (-255, 720, 597, 432)
# display_lines:  (1248, 720, 637, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34444      642.03]
# Right line average [    0.43908      151.77]
# AVERAGED LINES [[-226  720  609  432]
#  [1294  720  638  432]]
# Line-  [-226  720  609  432]
# Line-  [1294  720  638  432]
# CONTADOR -  2
# Center Points [[602 500]
#  [546 680]]
# display_lines:  (-226, 720, 609, 432)
# display_lines:  (1294, 720, 638, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3714      655.25]
# Right line average [    0.37388      197.46]
# AVERAGED LINES [[-174  720  601  432]
#  [1397  720  627  432]]
# Line-  [-174  720  601  432]
# Line-  [1397  720  627  432]
# CONTADOR -  2
# Center Points [[613 500]
#  [612 680]]
# display_lines:  (-174, 720, 601, 432)
# display_lines:  (1397, 720, 627, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36638      650.34]
# Right line average [    0.35586       212.6]
# AVERAGED LINES [[-190  720  595  432]
#  [1425  720  616  432]]
# Line-  [-190  720  595  432]
# Line-  [1425  720  616  432]
# CONTADOR -  2
# Center Points [[608 500]
#  [616 680]]
# display_lines:  (-190, 720, 595, 432)
# display_lines:  (1425, 720, 616, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.32289      629.86]
# Right line average [    0.38503      196.47]
# AVERAGED LINES [[-279  720  612  432]
#  [1359  720  611  432]]
# Line-  [-279  720  612  432]
# Line-  [1359  720  611  432]
# CONTADOR -  2
# Center Points [[594 500]
#  [550 680]]
# display_lines:  (-279, 720, 612, 432)
# display_lines:  (1359, 720, 611, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3613      647.06]
# Right line average [    0.40527       181.1]
# AVERAGED LINES [[-201  720  595  432]
#  [1329  720  619  432]]
# Line-  [-201  720  595  432]
# Line-  [1329  720  619  432]
# CONTADOR -  2
# Center Points [[597 500]
#  [570 680]]
# display_lines:  (-201, 720, 595, 432)
# display_lines:  (1329, 720, 619, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35416      653.66]
# Right line average [    0.36369      204.87]
# AVERAGED LINES [[-187  720  625  432]
#  [1416  720  624  432]]
# Line-  [-187  720  625  432]
# Line-  [1416  720  624  432]
# CONTADOR -  2
# Center Points [[622 500]
#  [616 680]]
# display_lines:  (-187, 720, 625, 432)
# display_lines:  (1416, 720, 624, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36091      656.08]
# Right line average [    0.37371      189.69]
# AVERAGED LINES [[-177  720  620  432]
#  [1419  720  648  432]]
# Line-  [-177  720  620  432]
# Line-  [1419  720  648  432]
# CONTADOR -  2
# Center Points [[631 500]
#  [623 680]]
# display_lines:  (-177, 720, 620, 432)
# display_lines:  (1419, 720, 648, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34334      642.68]
# Right line average [    0.31764      236.12]
# AVERAGED LINES [[-225  720  613  432]
#  [1523  720  616  432]]
# Line-  [-225  720  613  432]
# Line-  [1523  720  616  432]
# CONTADOR -  2
# Center Points [[623 500]
#  [645 680]]
# display_lines:  (-225, 720, 613, 432)
# display_lines:  (1523, 720, 616, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3602      649.79]
# Right line average [    0.39104       180.3]
# AVERAGED LINES [[-194  720  604  432]
#  [1380  720  643  432]]
# Line-  [-194  720  604  432]
# Line-  [1380  720  643  432]
# CONTADOR -  2
# Center Points [[616 500]
#  [597 680]]
# display_lines:  (-194, 720, 604, 432)
# display_lines:  (1380, 720, 643, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35429      645.91]
# Right line average [    0.34762      215.04]
# AVERAGED LINES [[-209  720  603  432]
#  [1452  720  624  432]]
# Line-  [-209  720  603  432]
# Line-  [1452  720  624  432]
# CONTADOR -  2
# Center Points [[615 500]
#  [621 680]]
# display_lines:  (-209, 720, 603, 432)
# display_lines:  (1452, 720, 624, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3589      649.25]
# Right line average [    0.31809      243.96]
# AVERAGED LINES [[-197  720  605  432]
#  [1496  720  591  432]]
# Line-  [-197  720  605  432]
# Line-  [1496  720  591  432]
# CONTADOR -  2
# Center Points [[610 500]
#  [643 680]]
# display_lines:  (-197, 720, 605, 432)
# display_lines:  (1496, 720, 591, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37213       652.6]
# Right line average [    0.29358      253.83]
# AVERAGED LINES [[-181  720  592  432]
#  [1587  720  606  432]]
# Line-  [-181  720  592  432]
# Line-  [1587  720  606  432]
# CONTADOR -  2
# Center Points [[623 500]
#  [689 680]]
# display_lines:  (-181, 720, 592, 432)
# display_lines:  (1587, 720, 606, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37331       658.6]
# Right line average [    0.29572      253.08]
# AVERAGED LINES [[-164  720  607  432]
#  [1578  720  605  432]]
# Line-  [-164  720  607  432]
# Line-  [1578  720  605  432]
# CONTADOR -  2
# Center Points [[629 500]
#  [693 680]]
# display_lines:  (-164, 720, 607, 432)
# display_lines:  (1578, 720, 605, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.38034       663.2]
# Right line average [    0.27992      268.41]
# AVERAGED LINES [[-149  720  607  432]
#  [1613  720  584  432]]
# Line-  [-149  720  607  432]
# Line-  [1613  720  584  432]
# CONTADOR -  2
# Center Points [[627 500]
#  [713 680]]
# display_lines:  (-149, 720, 607, 432)
# display_lines:  (1613, 720, 584, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.40179      672.95]
# Right line average [    0.31773      240.21]
# AVERAGED LINES [[-117  720  599  432]
#  [1510  720  603  432]]
# Line-  [-117  720  599  432]
# Line-  [1510  720  603  432]
# CONTADOR -  2
# Center Points [[623 500]
#  [684 680]]
# display_lines:  (-117, 720, 599, 432)
# display_lines:  (1510, 720, 603, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37851      658.64]
# Right line average [    0.36854      202.73]
# AVERAGED LINES [[-162  720  598  432]
#  [1403  720  622  432]]
# Line-  [-162  720  598  432]
# Line-  [1403  720  622  432]
# CONTADOR -  2
# Center Points [[612 500]
#  [619 680]]
# display_lines:  (-162, 720, 598, 432)
# display_lines:  (1403, 720, 622, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36357      651.76]
# Right line average [      0.321      241.83]
# AVERAGED LINES [[-187  720  604  432]
#  [1489  720  592  432]]
# Line-  [-187  720  604  432]
# Line-  [1489  720  592  432]
# CONTADOR -  2
# Center Points [[610 500]
#  [644 680]]
# display_lines:  (-187, 720, 604, 432)
# display_lines:  (1489, 720, 592, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.40193      665.45]
# Right line average [    0.32919      230.91]
# AVERAGED LINES [[-135  720  580  432]
#  [1485  720  610  432]]
# Line-  [-135  720  580  432]
# Line-  [1485  720  610  432]
# CONTADOR -  2
# Center Points [[614 500]
#  [664 680]]
# display_lines:  (-135, 720, 580, 432)
# display_lines:  (1485, 720, 610, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.38267      651.21]
# Right line average [    0.30496       245.5]
# AVERAGED LINES [[-179  720  572  432]
#  [1555  720  611  432]]
# Line-  [-179  720  572  432]
# Line-  [1555  720  611  432]
# CONTADOR -  2
# Center Points [[614 500]
#  [675 680]]
# display_lines:  (-179, 720, 572, 432)
# display_lines:  (1555, 720, 611, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.38267      651.21]
# Right line average [    0.30496       245.5]
# AVERAGED LINES [[-179  720  572  432]
#  [1555  720  611  432]]
# Line-  [-179  720  572  432]
# Line-  [1555  720  611  432]
# CONTADOR -  2
# Center Points [[614 500]
#  [675 680]]
# display_lines:  (-179, 720, 572, 432)
# display_lines:  (1555, 720, 611, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3704      646.98]
# Right line average [    0.35322      214.15]
# AVERAGED LINES [[-197  720  580  432]
#  [1432  720  616  432]]
# Line-  [-197  720  580  432]
# Line-  [1432  720  616  432]
# CONTADOR -  2
# Center Points [[602 500]
#  [615 680]]
# display_lines:  (-197, 720, 580, 432)
# display_lines:  (1432, 720, 616, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
# 0: 384x640 1 center, 1 line_left, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.39129      658.49]
# Right line average [    0.46296       123.5]
# AVERAGED LINES [[-157  720  578  432]
#  [1288  720  666  432]]
# Line-  [-157  720  578  432]
# Line-  [1288  720  666  432]
# CONTADOR -  2
# Center Points [[608 500]
#  [574 680]]
# display_lines:  (-157, 720, 578, 432)
# display_lines:  (1288, 720, 666, 432)
#
# 0: 384x640 1 center, 1 line_left, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37467      652.67]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-179  720  588  432]
#  [   0    0    0    0]]
# Line-  [-179  720  588  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250203    500]
#  [339964    680]]
# display_lines:  (-179, 720, 588, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.40081      665.65]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-135  720  582  432]
#  [   0    0    0    0]]
# Line-  [-135  720  582  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250206    500]
#  [339983    680]]
# display_lines:  (-135, 720, 582, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37167       648.6]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-192  720  582  432]
#  [   0    0    0    0]]
# Line-  [-192  720  582  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250200    500]
#  [339958    680]]
# display_lines:  (-192, 720, 582, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.39345      655.49]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-163  720  568  432]
#  [   0    0    0    0]]
# Line-  [-163  720  568  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250198    500]
#  [339970    680]]
# display_lines:  (-163, 720, 568, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.41334      666.25]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-130  720  566  432]
#  [   0    0    0    0]]
# Line-  [-130  720  566  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250201    500]
#  [339984    680]]
# display_lines:  (-130, 720, 566, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37747         648]
# Right line average [    0.27365      279.34]
# AVERAGED LINES [[-190  720  572  432]
#  [1610  720  557  432]]
# Line-  [-190  720  572  432]
# Line-  [1610  720  557  432]
# CONTADOR -  2
# Center Points [[599 500]
#  [690 680]]
# display_lines:  (-190, 720, 572, 432)
# display_lines:  (1610, 720, 557, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.42533       668.5]
# Right line average [     0.1854      349.51]
# AVERAGED LINES [[-121  720  556  432]
#  [1998  720  444  432]]
# Line-  [-121  720  556  432]
# Line-  [1998  720  444  432]
# CONTADOR -  2
# Center Points [[603 500]
#  [878 680]]
# display_lines:  (-121, 720, 556, 432)
# display_lines:  (1998, 720, 444, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.38995      650.84]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-177  720  561  432]
#  [   0    0    0    0]]
# Line-  [-177  720  561  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250193    500]
#  [339963    680]]
# display_lines:  (-177, 720, 561, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36679      639.13]
# Right line average [    0.38136      192.44]
# AVERAGED LINES [[-220  720  564  432]
#  [1383  720  628  432]]
# Line-  [-220  720  564  432]
# Line-  [1383  720  628  432]
# CONTADOR -  2
# Center Points [[592 500]
#  [584 680]]
# display_lines:  (-220, 720, 564, 432)
# display_lines:  (1383, 720, 628, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36615      642.34]
# Right line average [     0.3622      202.61]
# AVERAGED LINES [[-212  720  574  432]
#  [1428  720  633  432]]
# Line-  [-212  720  574  432]
# Line-  [1428  720  633  432]
# CONTADOR -  2
# Center Points [[604 500]
#  [608 680]]
# display_lines:  (-212, 720, 574, 432)
# display_lines:  (1428, 720, 633, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36313      641.91]
# Right line average [    0.34074         220]
# AVERAGED LINES [[-215  720  578  432]
#  [1467  720  622  432]]
# Line-  [-215  720  578  432]
# Line-  [1467  720  622  432]
# CONTADOR -  2
# Center Points [[606 500]
#  [623 680]]
# display_lines:  (-215, 720, 578, 432)
# display_lines:  (1467, 720, 622, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 26.9ms
# Speed: 3.0ms preprocess, 26.9ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 27.9ms
# Speed: 4.0ms preprocess, 27.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34999      630.67]
# Right line average [    0.42236      157.39]
# AVERAGED LINES [[-255  720  567  432]
#  [1332  720  650  432]]
# Line-  [-255  720  567  432]
# Line-  [1332  720  650  432]
# CONTADOR -  2
# Center Points [[592 500]
#  [549 680]]
# display_lines:  (-255, 720, 567, 432)
# display_lines:  (1332, 720, 650, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 41.9ms
# Speed: 5.0ms preprocess, 41.9ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 17.9ms
# Speed: 4.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35042      636.35]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-238  720  583  432]
#  [   0    0    0    0]]
# Line-  [-238  720  583  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250195    500]
#  [339939    680]]
# display_lines:  (-238, 720, 583, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3548      638.17]
# Right line average nan
# No line parameters
# AVERAGED LINES [[-230  720  581  432]
#  [   0    0    0    0]]
# Line-  [-230  720  581  432]
# Line-  [0 0 0 0]
# CONTADOR -  2
# Center Points [[250195    500]
#  [339942    680]]
# display_lines:  (-230, 720, 581, 432)
# display_lines:  (0, 0, 0, 0)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [     -0.347      645.45]
# Right line average [    0.34111      216.16]
# AVERAGED LINES [[-214  720  615  432]
#  [1477  720  632  432]]
# Line-  [-214  720  615  432]
# Line-  [1477  720  632  432]
# CONTADOR -  2
# Center Points [[625 500]
#  [631 680]]
# display_lines:  (-214, 720, 615, 432)
# display_lines:  (1477, 720, 632, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.34696      644.93]
# Right line average [    0.31782      233.35]
# AVERAGED LINES [[-216  720  613  432]
#  [1531  720  625  432]]
# Line-  [-216  720  613  432]
# Line-  [1531  720  625  432]
# CONTADOR -  2
# Center Points [[628 500]
#  [653 680]]
# display_lines:  (-216, 720, 613, 432)
# display_lines:  (1531, 720, 625, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36531       648.5]
# Right line average [    0.37963       185.4]
# AVERAGED LINES [[-195  720  592  432]
#  [1408  720  649  432]]
# Line-  [-195  720  592  432]
# Line-  [1408  720  649  432]
# CONTADOR -  2
# Center Points [[617 500]
#  [609 680]]
# display_lines:  (-195, 720, 592, 432)
# display_lines:  (1408, 720, 649, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.35222      644.75]
# Right line average [    0.32452      231.67]
# AVERAGED LINES [[-213  720  604  432]
#  [1504  720  617  432]]
# Line-  [-213  720  604  432]
# Line-  [1504  720  617  432]
# CONTADOR -  2
# Center Points [[619 500]
#  [641 680]]
# display_lines:  (-213, 720, 604, 432)
# display_lines:  (1504, 720, 617, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.38448      658.25]
# Right line average [    0.33456      217.78]
# AVERAGED LINES [[-160  720  588  432]
#  [1501  720  640  432]]
# Line-  [-160  720  588  432]
# Line-  [1501  720  640  432]
# CONTADOR -  2
# Center Points [[627 500]
#  [663 680]]
# display_lines:  (-160, 720, 588, 432)
# display_lines:  (1501, 720, 640, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.38448      658.25]
# Right line average [    0.33456      217.78]
# AVERAGED LINES [[-160  720  588  432]
#  [1501  720  640  432]]
# Line-  [-160  720  588  432]
# Line-  [1501  720  640  432]
# CONTADOR -  2
# Center Points [[627 500]
#  [663 680]]
# display_lines:  (-160, 720, 588, 432)
# display_lines:  (1501, 720, 640, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.36001      653.05]
# Right line average [    0.30883      232.94]
# AVERAGED LINES [[-185  720  613  432]
#  [1577  720  644  432]]
# Line-  [-185  720  613  432]
# Line-  [1577  720  644  432]
# CONTADOR -  2
# Center Points [[644 500]
#  [687 680]]
# display_lines:  (-185, 720, 613, 432)
# display_lines:  (1577, 720, 644, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 42.9ms
# Speed: 5.0ms preprocess, 42.9ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.39225      669.97]
# Right line average [    0.28768      250.01]
# AVERAGED LINES [[-127  720  606  432]
#  [1633  720  632  432]]
# Line-  [-127  720  606  432]
# Line-  [1633  720  632  432]
# CONTADOR -  2
# Center Points [[650 500]
#  [734 680]]
# display_lines:  (-127, 720, 606, 432)
# display_lines:  (1633, 720, 632, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 20.9ms
# Speed: 4.0ms preprocess, 20.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [    -0.3688      654.55]
# Right line average [    0.28859      252.85]
# AVERAGED LINES [[-177  720  603  432]
#  [1618  720  620  432]]
# Line-  [-177  720  603  432]
# Line-  [1618  720  620  432]
# CONTADOR -  2
# Center Points [[637 500]
#  [706 680]]
# display_lines:  (-177, 720, 603, 432)
# display_lines:  (1618, 720, 620, 432)
#
# 0: 384x640 1 center, 1 line_left, 2 line_rights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Left line average [   -0.37392      654.19]
# Right line average [    0.30986      237.63]
# AVERAGED LINES [[-175  720  594  432]
#  [1556  720  627  432]]
# Line-  [-175  720  594  432]
# Line-  [1556  720  627  432]
# CONTADOR -  2
# Center Points [[629 500]
#  [679 680]]
# display_lines:  (-175, 720, 594, 432)
# display_lines:  (1556, 720, 627, 432)
#
# 0: 384x640 1 center, 1 line_left, 1 line_right, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# **Código final**

# %%
# model = YOLO("./Yolov8/weights_train4/best.pt")  # segmentation model - past
model = YOLO("./Yolov8/weights_feb2024/best.pt")  # segmentation model - past
names = model.model.names
cap = cv2.VideoCapture("./Yolov8/carril.mp4")
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

out = cv2.VideoWriter('instance-segmentation-20.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    results = model.predict(im0)

    polylines_im = np.zeros((im0.shape[0], im0.shape[1], 1), np.uint8)
    height,width = polylines_im.shape[:2]
    if results[0].masks is not None:
        clss = results[0].boxes.cls.cpu().tolist()
        masks = results[0].masks.xy
        for mask, cls in zip(masks, clss):
            if mask is not None and names[int(cls)] == "center":
                cv2.polylines(polylines_im, [np.int32(mask)], isClosed=False, color=255, thickness=5)
    polylines_im = cv2.medianBlur(polylines_im, 7)
    polylines_im[height-100:height, 0:width] = 0
    lines = cv2.HoughLinesP(polylines_im, 5, np.pi/180, 100, np.array([]), minLineLength=100, maxLineGap=10)
    if lines is not None:
        averaged_lines = average_slope_intercept(im0, lines)
        line_image = display_lines(im0, averaged_lines)
        im0 = cv2.addWeighted(im0, 0.8, line_image, 1, 1)

    out.write(im0)
    cv2.imshow("instance-segmentation", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

out.release()
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# Codigo optimizado por la jetson

# %%
  def listener_callback(self, data):
    """
    Callback function.
    """
    # Display the message on the console
    self.get_logger().info('Receiving video frame')

    # Convert ROS Image message to OpenCV image
    current_frame = self.br.imgmsg_to_cv2(data)
    counter = self.counter + 1
    msg = Float64MultiArray()

    # Auxiliar images to display
    frame_gray = np.copy(current_frame)
    frame_gray = cv2.cvtColor(frame_gray, cv2.COLOR_BGR2GRAY)
    # combo_combo_image = frame_gray
    height,width = current_frame.shape[:2]
    polylines_im = np.zeros((height, width, 1), np.uint8)

    # YOLO predictions
    results = self.MODEL.predict(current_frame)
    if counter%2 == 0:    
      if results[0].masks is not None:
          clss = results[0].boxes.cls.cpu().tolist()
          masks = results[0].masks.xy
          for mask, cls in zip(masks, clss):
              if mask is not None and self.MODEL_NAMES[int(cls)] == "center":
                  cv2.polylines(polylines_im, [np.int32(mask)], isClosed=False, color=255, thickness=5)
          polylines_im[height-205:height, 0:width] = 0
          polylines_im[0:450, 0:width] = 0
          lines = cv2.HoughLinesP(polylines_im, 5, np.pi/180, 100, np.array([]), minLineLength=100, maxLineGap=10)
          if lines is not None:
              averaged_lines = average_slope_intercept(height, lines)
              if not np.isnan(averaged_lines).any():
                # line_image = display_lines(im0_gray, averaged_lines)
                center_points = center_pt(500,680,averaged_lines)
                for x1, y1, x2, y2 in averaged_lines:
                    # print("display_lines: ",(x1, y1, x2, y2))
                    cv2.line(frame_gray, (x1, y1), (x2, y2), (255, 0, 0), 10)
                for x, y in center_points:
                    cv2.circle(frame_gray, (x,y),1, (255, 0, 0), 5)
                # combo_image = cv2.addWeighted(im0_gray, 0.8, line_image, 1, 1)
                # center_point_image=makePoints(combo_image,center_points)
                # combo_combo_image=cv2.addWeighted(combo_image, 0.8, center_point_image, 1, 1)
                # Publish center points
                msg.data = center_points.flatten()
                self.publisher_center_pts.publish(msg)

    cv2.imshow('result',frame_gray)
    cv2.waitKey(1)
