# %% [markdown]
# # Pruebas Object Detection

# %%
import cv2
import numpy as np
import math
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# %%
# img = cv2.imread('bus.jpg')
model = YOLO('yolov8n.pt')
names = model.names
person_clss  = 0
print(names[person_clss])
# Out:
# person

# %% [markdown]
# ## VisionEye View With Distance Calculation
# Source: https://docs.ultralytics.com/guides/vision-eye/#samples

# %%
cap = cv2.VideoCapture("personas.mp4")

w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

print(f"Video frame width: {w}, height: {h}, fps: {fps}")
# out = cv2.VideoWriter('visioneye-distance-calculation.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))

center_point = (0, h)
pixel_per_meter = 10

txt_color, txt_background, bbox_clr = ((0, 0, 0), (255, 255, 255), (255, 0, 255))

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    annotator = Annotator(im0, line_width=2)

    results = model.track(im0, persist=True)
    results.plot()
    boxes = results[0].boxes.xyxy.cpu()


    if results[0].boxes.id is not None:
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for box, track_id in zip(boxes, track_ids):
            annotator.box_label(box, label=str(track_id), color=bbox_clr)
            annotator.visioneye(box, center_point)

            x1, y1 = int((box[0] + box[2]) // 2), int((box[1] + box[3]) // 2)    # Bounding box centroid

            distance = (math.sqrt((x1 - center_point[0]) ** 2 + (y1 - center_point[1]) ** 2))/pixel_per_meter

            text_size, _ = cv2.getTextSize(f"Distance: {distance:.2f} m", cv2.FONT_HERSHEY_SIMPLEX,1.2, 3)
            cv2.rectangle(im0, (x1, y1 - text_size[1] - 10),(x1 + text_size[0] + 10, y1), txt_background, -1)
            cv2.putText(im0, f"Distance: {distance:.2f} m",(x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 1.2,txt_color, 3)

    # out.write(im0)
    cv2.imshow("visioneye-distance-calculation", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# Video frame width: 0, height: 0, fps: 0
# Video frame is empty or video processing has been successfully completed.

# %% [markdown]
# ## Distance Calculation
#
# Source:
# * https://github.com/Asadullah-Dal17/Yolov4-Detector-and-Distance-Estimator/blob/master/DistanceEstimation.py
# * https://www.youtube.com/watch?v=FcRCwTgYXJw&ab_channel=AiPhile

# %% [markdown]
# ### Funciones Auxiliares

# %%
def focal_length_finder(measured_distance, real_width, width_in_frame):
    focal_length = (width_in_frame * measured_distance) / real_width
    return focal_length

# %%
def distance_finder(focal_length, real_width, width_in_frame):
    distance = (real_width * focal_length) / width_in_frame
    return distance

# %% [markdown]
# ### Detección y Calculo de distancia en Video

# %%
# Medidas en metros
KNOWN_DISTANCE = 2
PERSON_WIDTH = 0.38 # Ancho de una persona promedio - Medidas de Fri - 38 cm
MODE = "calibration"
VIDEO_PATH = "//home/fcanof/Documents/sdv_vision_notebooks/data/ref_video/2_personas.mp4"
cap = cv2.VideoCapture(VIDEO_PATH)
count = 0
while True:
    ret, frame = cap.read()

    results = model(frame, classes=0)
    if results[0].boxes is not None:
        boxes_w = results[0].boxes.xywh.cpu()
        boxes_xyxy = results[0].boxes.xyxy.cpu()
        for box_w, box_xyxy in zip(boxes_w, boxes_xyxy):
            print("Mode: ", MODE)
            person_width = box_w[2]
            person_height = box_w[3]
            x,y = int(box_xyxy[0]), int(box_xyxy[1]+(person_height-50))
            if MODE == "calibration":
                focal_person = focal_length_finder(KNOWN_DISTANCE, PERSON_WIDTH, person_width)
                print(f"Focal length: {focal_person}")
            else:
                distance = distance_finder(focal_person, PERSON_WIDTH, person_width)
                distance = round(float(distance), 3)
                print(f"Distance: {distance} meters")
            cv2.rectangle(frame, (x, y-1), (x+200, y+25), (0,0,255),-1 )
            text = "Distance "+str(distance)+" meters"
            cv2.putText(frame, text, (x+10,y+20), cv2.FONT_HERSHEY_SIMPLEX, 0.48, (255,255,255), 2)

    cv2.imshow('frame',frame)
    count += 1
    if count == 100:
        MODE = "distance"
    key = cv2.waitKey(1)
    if key ==ord('q'):
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# 0: 384x640 1 person, 80.4ms
# Speed: 4.5ms preprocess, 80.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2695.093994140625
#
# 0: 384x640 1 person, 140.3ms
# Speed: 4.9ms preprocess, 140.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2966.550537109375
#
# 0: 384x640 1 person, 78.9ms
# Speed: 2.7ms preprocess, 78.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3079.9150390625
#
# 0: 384x640 1 person, 71.0ms
# Speed: 2.4ms preprocess, 71.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2589.5810546875
#
# 0: 384x640 2 persons, 72.5ms
# Speed: 2.6ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3044.8251953125
# Mode:  calibration
# Focal length: 3853.72265625
#
# 0: 384x640 2 persons, 73.3ms
# Speed: 1.8ms preprocess, 73.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3380.022705078125
# Mode:  calibration
# Focal length: 1247.1439208984375
#
# 0: 384x640 1 person, 73.0ms
# Speed: 2.1ms preprocess, 73.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3461.170654296875
#
# 0: 384x640 1 person, 74.2ms
# Speed: 3.1ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2722.755126953125
#
# 0: 384x640 1 person, 70.9ms
# Speed: 2.0ms preprocess, 70.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 4049.83642578125
#
# 0: 384x640 1 person, 83.9ms
# Speed: 2.1ms preprocess, 83.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3835.62841796875
#
# 0: 384x640 1 person, 75.0ms
# Speed: 2.6ms preprocess, 75.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 4058.915771484375
#
# 0: 384x640 2 persons, 72.8ms
# Speed: 2.4ms preprocess, 72.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3842.44384765625
# Mode:  calibration
# Focal length: 1410.7130126953125
#
# 0: 384x640 1 person, 69.8ms
# Speed: 2.4ms preprocess, 69.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3451.859619140625
#
# 0: 384x640 1 person, 67.9ms
# Speed: 2.0ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3474.82666015625
#
# 0: 384x640 2 persons, 74.1ms
# Speed: 2.3ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3267.68408203125
# Mode:  calibration
# Focal length: 893.7537231445312
#
# 0: 384x640 1 person, 63.8ms
# Speed: 2.3ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3321.810791015625
#
# 0: 384x640 1 person, 67.7ms
# Speed: 2.3ms preprocess, 67.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3107.76318359375
#
# 0: 384x640 1 person, 70.8ms
# Speed: 3.2ms preprocess, 70.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 3079.222412109375
#
# 0: 384x640 1 person, 70.7ms
# Speed: 3.2ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2987.890380859375
#
# 0: 384x640 1 person, 63.1ms
# Speed: 2.4ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2934.75244140625
#
# 0: 384x640 1 person, 66.8ms
# Speed: 1.9ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2905.778564453125
#
# 0: 384x640 1 person, 85.1ms
# Speed: 1.8ms preprocess, 85.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2918.29345703125
#
# 0: 384x640 1 person, 67.6ms
# Speed: 2.2ms preprocess, 67.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2929.60009765625
#
# 0: 384x640 1 person, 61.4ms
# Speed: 2.3ms preprocess, 61.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2893.447509765625
#
# 0: 384x640 1 person, 57.7ms
# Speed: 1.9ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2935.1298828125
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2945.03466796875
#
# 0: 384x640 1 person, 61.7ms
# Speed: 1.7ms preprocess, 61.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2810.40771484375
#
# 0: 384x640 1 person, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2634.2646484375
#
# 0: 384x640 1 person, 55.2ms
# Speed: 2.1ms preprocess, 55.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2653.155517578125
#
# 0: 384x640 1 person, 53.5ms
# Speed: 2.1ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2523.717529296875
#
# 0: 384x640 1 person, 46.4ms
# Speed: 1.8ms preprocess, 46.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2406.024169921875
#
# 0: 384x640 1 person, 57.3ms
# Speed: 1.9ms preprocess, 57.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2264.199462890625
#
# 0: 384x640 1 person, 52.6ms
# Speed: 2.1ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 2106.97119140625
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.7ms preprocess, 45.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1977.044189453125
#
# 0: 384x640 1 person, 55.6ms
# Speed: 2.1ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1891.1392822265625
#
# 0: 384x640 1 person, 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1847.421875
#
# 0: 384x640 1 person, 56.8ms
# Speed: 2.3ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1790.7354736328125
#
# 0: 384x640 1 person, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1772.1082763671875
#
# 0: 384x640 1 person, 57.4ms
# Speed: 1.8ms preprocess, 57.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1751.2230224609375
#
# 0: 384x640 1 person, 56.2ms
# Speed: 2.4ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1733.2235107421875
#
# 0: 384x640 1 person, 57.5ms
# Speed: 1.8ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1714.2196044921875
#
# 0: 384x640 1 person, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1709.90185546875
#
# 0: 384x640 1 person, 63.1ms
# Speed: 1.6ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1704.7015380859375
#
# 0: 384x640 1 person, 61.1ms
# Speed: 2.1ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1705.9454345703125
#
# 0: 384x640 1 person, 62.7ms
# Speed: 2.0ms preprocess, 62.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1699.701416015625
#
# 0: 384x640 1 person, 54.1ms
# Speed: 2.5ms preprocess, 54.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1672.8214111328125
#
# 0: 384x640 1 person, 51.3ms
# Speed: 1.9ms preprocess, 51.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1654.9483642578125
#
# 0: 384x640 1 person, 54.4ms
# Speed: 1.7ms preprocess, 54.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1653.4947509765625
#
# 0: 384x640 1 person, 52.9ms
# Speed: 1.8ms preprocess, 52.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1613.9775390625
#
# 0: 384x640 1 person, 71.3ms
# Speed: 2.5ms preprocess, 71.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1549.9595947265625
#
# 0: 384x640 1 person, 68.2ms
# Speed: 3.3ms preprocess, 68.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1430.8568115234375
#
# 0: 384x640 1 person, 73.0ms
# Speed: 2.6ms preprocess, 73.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1388.9967041015625
#
# 0: 384x640 1 person, 60.4ms
# Speed: 2.1ms preprocess, 60.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1289.72509765625
#
# 0: 384x640 1 person, 61.8ms
# Speed: 2.1ms preprocess, 61.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1130.794189453125
#
# 0: 384x640 1 person, 59.0ms
# Speed: 1.7ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 971.3399658203125
#
# 0: 384x640 1 person, 64.8ms
# Speed: 1.5ms preprocess, 64.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 925.7786865234375
#
# 0: 384x640 1 person, 60.3ms
# Speed: 2.2ms preprocess, 60.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 924.7333984375
#
# 0: 384x640 1 person, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 904.2296142578125
#
# 0: 384x640 1 person, 65.9ms
# Speed: 2.0ms preprocess, 65.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 927.9157104492188
#
# 0: 384x640 1 person, 68.7ms
# Speed: 2.4ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1030.046142578125
#
# 0: 384x640 1 person, 71.2ms
# Speed: 2.4ms preprocess, 71.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1103.092529296875
#
# 0: 384x640 1 person, 78.1ms
# Speed: 2.4ms preprocess, 78.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1154.559326171875
#
# 0: 384x640 1 person, 61.7ms
# Speed: 2.2ms preprocess, 61.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1188.2181396484375
#
# 0: 384x640 1 person, 64.8ms
# Speed: 1.9ms preprocess, 64.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1191.861572265625
#
# 0: 384x640 1 person, 60.6ms
# Speed: 2.2ms preprocess, 60.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1164.864990234375
#
# 0: 384x640 1 person, 64.9ms
# Speed: 1.7ms preprocess, 64.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1109.0767822265625
#
# 0: 384x640 1 person, 61.1ms
# Speed: 2.1ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1042.4652099609375
#
# 0: 384x640 1 person, 62.1ms
# Speed: 2.1ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 978.0103149414062
#
# 0: 384x640 1 person, 66.4ms
# Speed: 1.7ms preprocess, 66.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 900.7213745117188
#
# 0: 384x640 1 person, 63.0ms
# Speed: 1.6ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 831.06982421875
#
# 0: 384x640 1 person, 59.7ms
# Speed: 1.9ms preprocess, 59.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 745.5931396484375
#
# 0: 384x640 1 person, 61.6ms
# Speed: 2.4ms preprocess, 61.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 775.0307006835938
#
# 0: 384x640 1 person, 61.2ms
# Speed: 1.7ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 866.3367309570312
#
# 0: 384x640 1 person, 63.7ms
# Speed: 1.8ms preprocess, 63.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 945.2211303710938
#
# 0: 384x640 1 person, 70.4ms
# Speed: 2.0ms preprocess, 70.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1044.5169677734375
#
# 0: 384x640 1 person, 72.9ms
# Speed: 2.7ms preprocess, 72.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1208.7625732421875
#
# 0: 384x640 1 person, 61.9ms
# Speed: 2.5ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1292.7841796875
#
# 0: 384x640 1 person, 60.2ms
# Speed: 1.9ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1426.899658203125
#
# 0: 384x640 1 person, 58.0ms
# Speed: 1.7ms preprocess, 58.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1485.400390625
#
# 0: 384x640 1 person, 59.6ms
# Speed: 1.8ms preprocess, 59.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1505.345703125
#
# 0: 384x640 1 person, 57.1ms
# Speed: 1.5ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1501.494873046875
#
# 0: 384x640 1 person, 50.4ms
# Speed: 1.7ms preprocess, 50.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1465.4852294921875
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.3ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1401.5181884765625
#
# 0: 384x640 1 person, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1307.2550048828125
#
# 0: 384x640 1 person, 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1214.96630859375
#
# 0: 384x640 1 person, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1172.8006591796875
#
# 0: 384x640 1 person, 55.1ms
# Speed: 2.2ms preprocess, 55.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1083.1533203125
#
# 0: 384x640 1 person, 59.5ms
# Speed: 2.5ms preprocess, 59.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 1027.173828125
#
# 0: 384x640 1 person, 60.3ms
# Speed: 2.2ms preprocess, 60.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 989.6884155273438
#
# 0: 384x640 1 person, 65.4ms
# Speed: 2.5ms preprocess, 65.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 958.8396606445312
#
# 0: 384x640 1 person, 69.9ms
# Speed: 2.4ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 943.83642578125
#
# 0: 384x640 1 person, 63.7ms
# Speed: 2.5ms preprocess, 63.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 937.3501586914062
#
# 0: 384x640 1 person, 70.7ms
# Speed: 2.1ms preprocess, 70.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 932.4798583984375
#
# 0: 384x640 1 person, 67.2ms
# Speed: 2.8ms preprocess, 67.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 937.4625854492188
#
# 0: 384x640 1 person, 65.1ms
# Speed: 2.4ms preprocess, 65.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 953.4666748046875
#
# 0: 384x640 1 person, 69.9ms
# Speed: 2.4ms preprocess, 69.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 953.7008056640625
#
# 0: 384x640 1 person, 78.0ms
# Speed: 2.2ms preprocess, 78.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 960.4718627929688
#
# 0: 384x640 1 person, 95.9ms
# Speed: 4.1ms preprocess, 95.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 944.6250610351562
#
# 0: 384x640 1 person, 72.5ms
# Speed: 2.4ms preprocess, 72.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 943.1610107421875
#
# 0: 384x640 1 person, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Focal length: 934.0584106445312
#
# 0: 384x640 1 person, 70.2ms
# Speed: 2.6ms preprocess, 70.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.033 meters
#
# 0: 384x640 1 person, 75.9ms
# Speed: 2.1ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.058 meters
#
# 0: 384x640 1 person, 67.6ms
# Speed: 2.1ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.094 meters
#
# 0: 384x640 1 person, 72.4ms
# Speed: 1.7ms preprocess, 72.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.112 meters
#
# 0: 384x640 1 person, 66.4ms
# Speed: 2.6ms preprocess, 66.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.166 meters
#
# 0: 384x640 1 person, 72.5ms
# Speed: 2.2ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.257 meters
#
# 0: 384x640 1 person, 73.7ms
# Speed: 2.9ms preprocess, 73.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.292 meters
#
# 0: 384x640 1 person, 69.9ms
# Speed: 1.9ms preprocess, 69.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.36 meters
#
# 0: 384x640 1 person, 71.1ms
# Speed: 2.4ms preprocess, 71.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.4 meters
#
# 0: 384x640 1 person, 70.0ms
# Speed: 2.6ms preprocess, 70.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.436 meters
#
# 0: 384x640 1 person, 79.2ms
# Speed: 2.1ms preprocess, 79.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.415 meters
#
# 0: 384x640 1 person, 76.8ms
# Speed: 2.9ms preprocess, 76.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.395 meters
#
# 0: 384x640 1 person, 70.4ms
# Speed: 1.8ms preprocess, 70.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.411 meters
#
# 0: 384x640 1 person, 70.4ms
# Speed: 2.5ms preprocess, 70.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.383 meters
#
# 0: 384x640 1 person, 70.4ms
# Speed: 2.2ms preprocess, 70.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.375 meters
#
# 0: 384x640 1 person, 73.2ms
# Speed: 2.9ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.338 meters
#
# 0: 384x640 1 person, 66.7ms
# Speed: 2.5ms preprocess, 66.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.305 meters
#
# 0: 384x640 1 person, 67.5ms
# Speed: 2.1ms preprocess, 67.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.292 meters
#
# 0: 384x640 1 person, 67.7ms
# Speed: 2.1ms preprocess, 67.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.289 meters
#
# 0: 384x640 1 person, 72.1ms
# Speed: 1.7ms preprocess, 72.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.292 meters
#
# 0: 384x640 1 person, 76.0ms
# Speed: 2.1ms preprocess, 76.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.309 meters
#
# 0: 384x640 1 person, 69.8ms
# Speed: 2.5ms preprocess, 69.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.317 meters
#
# 0: 384x640 1 person, 78.5ms
# Speed: 2.0ms preprocess, 78.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.321 meters
#
# 0: 384x640 1 person, 70.1ms
# Speed: 2.6ms preprocess, 70.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.316 meters
#
# 0: 384x640 1 person, 70.3ms
# Speed: 2.5ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.304 meters
#
# 0: 384x640 1 person, 69.9ms
# Speed: 2.3ms preprocess, 69.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.279 meters
#
# 0: 384x640 1 person, 69.1ms
# Speed: 1.9ms preprocess, 69.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.255 meters
#
# 0: 384x640 1 person, 69.1ms
# Speed: 2.3ms preprocess, 69.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.218 meters
#
# 0: 384x640 1 person, 68.3ms
# Speed: 2.0ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.183 meters
#
# 0: 384x640 1 person, 67.1ms
# Speed: 2.1ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.118 meters
#
# 0: 384x640 1 person, 68.0ms
# Speed: 2.2ms preprocess, 68.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.069 meters
#
# 0: 384x640 1 person, 74.8ms
# Speed: 2.7ms preprocess, 74.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.038 meters
#
# 0: 384x640 1 person, 65.8ms
# Speed: 2.3ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.031 meters
#
# 0: 384x640 1 person, 70.0ms
# Speed: 2.2ms preprocess, 70.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.033 meters
#
# 0: 384x640 1 person, 69.7ms
# Speed: 2.0ms preprocess, 69.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.04 meters
#
# 0: 384x640 1 person, 67.5ms
# Speed: 2.7ms preprocess, 67.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.071 meters
#
# 0: 384x640 1 person, 71.9ms
# Speed: 2.2ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.126 meters
#
# 0: 384x640 1 person, 67.0ms
# Speed: 2.6ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.187 meters
#
# 0: 384x640 1 person, 64.9ms
# Speed: 2.9ms preprocess, 64.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.226 meters
#
# 0: 384x640 1 person, 66.8ms
# Speed: 1.7ms preprocess, 66.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.278 meters
#
# 0: 384x640 1 person, 69.3ms
# Speed: 1.8ms preprocess, 69.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.31 meters
#
# 0: 384x640 1 person, 66.4ms
# Speed: 2.3ms preprocess, 66.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.338 meters
#
# 0: 384x640 1 person, 68.8ms
# Speed: 3.0ms preprocess, 68.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.323 meters
#
# 0: 384x640 1 person, 66.3ms
# Speed: 2.2ms preprocess, 66.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.302 meters
#
# 0: 384x640 1 person, 73.5ms
# Speed: 2.5ms preprocess, 73.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.279 meters
#
# 0: 384x640 1 person, 68.5ms
# Speed: 2.2ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.235 meters
#
# 0: 384x640 1 person, 56.9ms
# Speed: 2.4ms preprocess, 56.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.2 meters
#
# 0: 384x640 1 person, 52.5ms
# Speed: 2.2ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.175 meters
#
# 0: 384x640 1 person, 60.7ms
# Speed: 2.2ms preprocess, 60.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.159 meters
#
# 0: 384x640 1 person, 58.0ms
# Speed: 1.6ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.146 meters
#
# 0: 384x640 1 person, 61.2ms
# Speed: 2.2ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.139 meters
#
# 0: 384x640 1 person, 58.6ms
# Speed: 2.1ms preprocess, 58.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.142 meters
#
# 0: 384x640 1 person, 57.1ms
# Speed: 2.2ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.156 meters
#
# 0: 384x640 1 person, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.174 meters
#
# 0: 384x640 1 person, 58.6ms
# Speed: 2.1ms preprocess, 58.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.202 meters
#
# 0: 384x640 1 person, 56.6ms
# Speed: 2.1ms preprocess, 56.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.239 meters
#
# 0: 384x640 1 person, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.276 meters
#
# 0: 384x640 1 person, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.299 meters
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.3ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.324 meters
#
# 0: 384x640 1 person, 61.5ms
# Speed: 2.2ms preprocess, 61.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.348 meters
#
# 0: 384x640 1 person, 59.2ms
# Speed: 2.0ms preprocess, 59.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.365 meters
#
# 0: 384x640 1 person, 57.4ms
# Speed: 2.1ms preprocess, 57.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.364 meters
#
# 0: 384x640 1 person, 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.354 meters
#
# 0: 384x640 1 person, 57.7ms
# Speed: 2.3ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.339 meters
#
# 0: 384x640 1 person, 59.2ms
# Speed: 1.9ms preprocess, 59.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.317 meters
#
# 0: 384x640 1 person, 52.5ms
# Speed: 1.6ms preprocess, 52.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.299 meters
#
# 0: 384x640 1 person, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.277 meters
#
# 0: 384x640 1 person, 50.8ms
# Speed: 1.8ms preprocess, 50.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.264 meters
#
# 0: 384x640 1 person, 58.0ms
# Speed: 1.6ms preprocess, 58.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.241 meters
#
# 0: 384x640 1 person, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.228 meters
#
# 0: 384x640 1 person, 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.219 meters
#
# 0: 384x640 1 person, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.226 meters
#
# 0: 384x640 1 person, 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.228 meters
#
# 0: 384x640 1 person, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.229 meters
#
# 0: 384x640 1 person, 51.3ms
# Speed: 1.6ms preprocess, 51.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.232 meters
#
# 0: 384x640 1 person, 57.5ms
# Speed: 2.2ms preprocess, 57.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.235 meters
#
# 0: 384x640 1 person, 58.6ms
# Speed: 1.9ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.242 meters
#
# 0: 384x640 1 person, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.247 meters
#
# 0: 384x640 1 person, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.247 meters
#
# 0: 384x640 1 person, 61.8ms
# Speed: 1.9ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.245 meters
#
# 0: 384x640 1 person, 58.0ms
# Speed: 3.3ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.238 meters
#
# 0: 384x640 1 person, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.236 meters
#
# 0: 384x640 1 person, 51.1ms
# Speed: 1.8ms preprocess, 51.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.232 meters
#
# 0: 384x640 1 person, 58.8ms
# Speed: 1.8ms preprocess, 58.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.226 meters
#
# 0: 384x640 1 person, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.229 meters
#
# 0: 384x640 1 person, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.227 meters
#
# 0: 384x640 1 person, 56.4ms
# Speed: 3.3ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.23 meters
#
# 0: 384x640 1 person, 55.2ms
# Speed: 1.9ms preprocess, 55.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.242 meters
#
# 0: 384x640 1 person, 58.8ms
# Speed: 1.7ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.246 meters
#
# 0: 384x640 1 person, 57.6ms
# Speed: 1.9ms preprocess, 57.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.255 meters
#
# 0: 384x640 1 person, 49.4ms
# Speed: 2.3ms preprocess, 49.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.266 meters
#
# 0: 384x640 1 person, 65.2ms
# Speed: 1.7ms preprocess, 65.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.265 meters
#
# 0: 384x640 1 person, 94.2ms
# Speed: 4.3ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.276 meters
#
# 0: 384x640 1 person, 77.3ms
# Speed: 1.8ms preprocess, 77.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.283 meters
#
# 0: 384x640 1 person, 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.28 meters
#
# 0: 384x640 1 person, 60.3ms
# Speed: 1.8ms preprocess, 60.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.291 meters
#
# 0: 384x640 1 person, 54.8ms
# Speed: 2.1ms preprocess, 54.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.29 meters
#
# 0: 384x640 1 person, 59.2ms
# Speed: 1.9ms preprocess, 59.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.285 meters
#
# 0: 384x640 1 person, 56.3ms
# Speed: 1.7ms preprocess, 56.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.29 meters
#
# 0: 384x640 1 person, 57.8ms
# Speed: 2.2ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.283 meters
#
# 0: 384x640 1 person, 57.6ms
# Speed: 2.2ms preprocess, 57.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.28 meters
#
# 0: 384x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.285 meters
#
# 0: 384x640 1 person, 57.1ms
# Speed: 2.4ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.286 meters
#
# 0: 384x640 1 person, 55.2ms
# Speed: 1.6ms preprocess, 55.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.29 meters
#
# 0: 384x640 1 person, 66.2ms
# Speed: 2.3ms preprocess, 66.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.292 meters
#
# 0: 384x640 1 person, 61.6ms
# Speed: 2.9ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.299 meters
#
# 0: 384x640 1 person, 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.317 meters
#
# 0: 384x640 1 person, 58.6ms
# Speed: 2.2ms preprocess, 58.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.366 meters
#
# 0: 384x640 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.405 meters
#
# 0: 384x640 1 person, 57.4ms
# Speed: 1.6ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.406 meters
#
# 0: 384x640 1 person, 57.9ms
# Speed: 1.9ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.424 meters
#
# 0: 384x640 1 person, 69.5ms
# Speed: 2.2ms preprocess, 69.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.434 meters
#
# 0: 384x640 1 person, 69.3ms
# Speed: 2.0ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.44 meters
#
# 0: 384x640 1 person, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.439 meters
#
# 0: 384x640 1 person, 67.7ms
# Speed: 1.9ms preprocess, 67.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.446 meters
#
# 0: 384x640 1 person, 70.7ms
# Speed: 2.2ms preprocess, 70.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.453 meters
#
# 0: 384x640 1 person, 70.6ms
# Speed: 2.2ms preprocess, 70.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.44 meters
#
# 0: 384x640 1 person, 68.8ms
# Speed: 2.2ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.426 meters
#
# 0: 384x640 1 person, 66.7ms
# Speed: 2.1ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.398 meters
#
# 0: 384x640 1 person, 68.4ms
# Speed: 1.7ms preprocess, 68.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.363 meters
#
# 0: 384x640 1 person, 69.1ms
# Speed: 2.3ms preprocess, 69.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.306 meters
#
# 0: 384x640 1 person, 66.3ms
# Speed: 2.1ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.281 meters
#
# 0: 384x640 1 person, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.295 meters
#
# 0: 384x640 1 person, 74.9ms
# Speed: 2.3ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.31 meters
#
# 0: 384x640 1 person, 69.1ms
# Speed: 3.1ms preprocess, 69.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.327 meters
#
# 0: 384x640 1 person, 67.0ms
# Speed: 2.3ms preprocess, 67.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.359 meters
#
# 0: 384x640 1 person, 67.6ms
# Speed: 2.1ms preprocess, 67.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.422 meters
#
# 0: 384x640 1 person, 65.8ms
# Speed: 2.4ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.481 meters
#
# 0: 384x640 1 person, 65.7ms
# Speed: 1.8ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.529 meters
#
# 0: 384x640 1 person, 65.8ms
# Speed: 2.1ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.54 meters
#
# 0: 384x640 1 person, 65.2ms
# Speed: 2.5ms preprocess, 65.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.543 meters
#
# 0: 384x640 1 person, 66.0ms
# Speed: 2.4ms preprocess, 66.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.547 meters
#
# 0: 384x640 1 person, 67.4ms
# Speed: 2.3ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.542 meters
#
# 0: 384x640 1 person, 67.2ms
# Speed: 2.5ms preprocess, 67.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.544 meters
#
# 0: 384x640 1 person, 66.0ms
# Speed: 3.2ms preprocess, 66.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.543 meters
#
# 0: 384x640 1 person, 66.2ms
# Speed: 2.3ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.545 meters
#
# 0: 384x640 1 person, 67.2ms
# Speed: 1.9ms preprocess, 67.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.551 meters
#
# 0: 384x640 1 person, 64.8ms
# Speed: 2.4ms preprocess, 64.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.556 meters
#
# 0: 384x640 1 person, 66.0ms
# Speed: 2.2ms preprocess, 66.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.553 meters
#
# 0: 384x640 1 person, 68.9ms
# Speed: 3.3ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.498 meters
#
# 0: 384x640 1 person, 71.0ms
# Speed: 2.1ms preprocess, 71.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.523 meters
#
# 0: 384x640 1 person, 67.9ms
# Speed: 2.3ms preprocess, 67.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.527 meters
#
# 0: 384x640 1 person, 68.6ms
# Speed: 2.4ms preprocess, 68.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.543 meters
#
# 0: 384x640 1 person, 67.4ms
# Speed: 1.7ms preprocess, 67.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.487 meters
#
# 0: 384x640 1 person, 64.4ms
# Speed: 1.9ms preprocess, 64.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.272 meters
#
# 0: 384x640 1 person, 68.7ms
# Speed: 1.8ms preprocess, 68.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 2.032 meters
#
# 0: 384x640 1 person, 61.3ms
# Speed: 2.5ms preprocess, 61.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.933 meters
#
# 0: 384x640 1 person, 71.2ms
# Speed: 2.1ms preprocess, 71.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.896 meters
#
# 0: 384x640 1 person, 71.1ms
# Speed: 2.3ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.798 meters
#
# 0: 384x640 1 person, 68.1ms
# Speed: 2.1ms preprocess, 68.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.769 meters
#
# 0: 384x640 1 person, 68.5ms
# Speed: 2.6ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.736 meters
#
# 0: 384x640 1 person, 68.3ms
# Speed: 1.9ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.701 meters
#
# 0: 384x640 1 person, 85.8ms
# Speed: 2.5ms preprocess, 85.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.675 meters
#
# 0: 384x640 1 person, 93.3ms
# Speed: 8.5ms preprocess, 93.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.665 meters
#
# 0: 384x640 1 person, 67.5ms
# Speed: 2.1ms preprocess, 67.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.664 meters
#
# 0: 384x640 1 person, 67.6ms
# Speed: 1.9ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.655 meters
#
# 0: 384x640 1 person, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.654 meters
#
# 0: 384x640 1 person, 77.0ms
# Speed: 2.3ms preprocess, 77.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.657 meters
#
# 0: 384x640 1 person, 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.668 meters
#
# 0: 384x640 1 person, 67.6ms
# Speed: 2.4ms preprocess, 67.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.686 meters
#
# 0: 384x640 1 person, 66.5ms
# Speed: 2.2ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.699 meters
#
# 0: 384x640 1 person, 68.1ms
# Speed: 1.9ms preprocess, 68.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.721 meters
#
# 0: 384x640 1 person, 84.2ms
# Speed: 2.5ms preprocess, 84.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.73 meters
#
# 0: 384x640 1 person, 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.738 meters
#
# 0: 384x640 1 person, 67.7ms
# Speed: 2.3ms preprocess, 67.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.731 meters
#
# 0: 384x640 1 person, 67.0ms
# Speed: 2.7ms preprocess, 67.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.736 meters
#
# 0: 384x640 1 person, 66.1ms
# Speed: 1.8ms preprocess, 66.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.735 meters
#
# 0: 384x640 1 person, 69.1ms
# Speed: 1.7ms preprocess, 69.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.708 meters
#
# 0: 384x640 1 person, 66.9ms
# Speed: 2.2ms preprocess, 66.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.656 meters
#
# 0: 384x640 1 person, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.617 meters
#
# 0: 384x640 1 person, 56.8ms
# Speed: 1.9ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.577 meters
#
# 0: 384x640 1 person, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.555 meters
#
# 0: 384x640 1 person, 55.2ms
# Speed: 1.9ms preprocess, 55.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.546 meters
#
# 0: 384x640 1 person, 57.2ms
# Speed: 1.8ms preprocess, 57.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.539 meters
#
# 0: 384x640 1 person, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.532 meters
#
# 0: 384x640 1 person, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.527 meters
#
# 0: 384x640 1 person, 53.9ms
# Speed: 2.2ms preprocess, 53.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.527 meters
#
# 0: 384x640 1 person, 57.5ms
# Speed: 1.7ms preprocess, 57.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.525 meters
#
# 0: 384x640 1 person, 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.524 meters
#
# 0: 384x640 1 person, 51.5ms
# Speed: 2.1ms preprocess, 51.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.527 meters
#
# 0: 384x640 1 person, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.53 meters
#
# 0: 384x640 1 person, 46.2ms
# Speed: 2.2ms preprocess, 46.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.537 meters
#
# 0: 384x640 1 person, 57.9ms
# ...
#
# 0: 384x640 2 persons, 49.7ms
# Speed: 1.5ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.175 meters
# Mode:  distance
# Distance: 2.011 meters
#
# 0: 384x640 2 persons, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.994 meters
# Mode:  distance
# Distance: 1.174 meters
#
# 0: 384x640 2 persons, 55.9ms
# Speed: 2.5ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.949 meters
# Mode:  distance
# Distance: 1.17 meters
#
# 0: 384x640 2 persons, 56.9ms
# Speed: 1.9ms preprocess, 56.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.925 meters
# Mode:  distance
# Distance: 1.165 meters
#
# 0: 384x640 2 persons, 55.3ms
# Speed: 1.8ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.159 meters
# Mode:  distance
# Distance: 1.905 meters
#
# 0: 384x640 2 persons, 69.6ms
# Speed: 1.6ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.888 meters
# Mode:  distance
# Distance: 1.156 meters
#
# 0: 384x640 2 persons, 63.7ms
# Speed: 20.6ms preprocess, 63.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.152 meters
# Mode:  distance
# Distance: 1.852 meters
#
# 0: 384x640 2 persons, 56.4ms
# Speed: 1.9ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.151 meters
# Mode:  distance
# Distance: 1.824 meters
#
# 0: 384x640 2 persons, 56.3ms
# Speed: 1.8ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.806 meters
# Mode:  distance
# Distance: 1.149 meters
#
# 0: 384x640 2 persons, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.78 meters
# Mode:  distance
# Distance: 1.145 meters
#
# 0: 384x640 2 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.725 meters
# Mode:  distance
# Distance: 1.141 meters
#
# 0: 384x640 2 persons, 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.682 meters
# Mode:  distance
# Distance: 1.139 meters
#
# 0: 384x640 2 persons, 68.7ms
# Speed: 2.0ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.634 meters
# Mode:  distance
# Distance: 1.138 meters
#
# 0: 384x640 2 persons, 56.6ms
# Speed: 1.5ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.571 meters
# Mode:  distance
# Distance: 1.137 meters
#
# 0: 384x640 2 persons, 58.2ms
# Speed: 2.2ms preprocess, 58.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.54 meters
# Mode:  distance
# Distance: 1.14 meters
#
# 0: 384x640 2 persons, 60.1ms
# Speed: 2.1ms preprocess, 60.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.508 meters
# Mode:  distance
# Distance: 1.141 meters
#
# 0: 384x640 2 persons, 58.6ms
# Speed: 2.2ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.483 meters
# Mode:  distance
# Distance: 1.143 meters
#
# 0: 384x640 2 persons, 54.0ms
# Speed: 2.2ms preprocess, 54.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.435 meters
# Mode:  distance
# Distance: 1.142 meters
#
# 0: 384x640 2 persons, 59.9ms
# Speed: 1.5ms preprocess, 59.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.417 meters
# Mode:  distance
# Distance: 1.143 meters
#
# 0: 384x640 2 persons, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.381 meters
# Mode:  distance
# Distance: 1.141 meters
#
# 0: 384x640 2 persons, 69.4ms
# Speed: 2.2ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.141 meters
# Mode:  distance
# Distance: 1.359 meters
#
# 0: 384x640 2 persons, 54.5ms
# Speed: 1.8ms preprocess, 54.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.351 meters
# Mode:  distance
# Distance: 1.143 meters
#
# 0: 384x640 2 persons, 58.7ms
# Speed: 2.3ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.144 meters
# Mode:  distance
# Distance: 1.328 meters
#
# 0: 384x640 2 persons, 51.1ms
# Speed: 1.7ms preprocess, 51.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.146 meters
# Mode:  distance
# Distance: 1.307 meters
#
# 0: 384x640 2 persons, 62.5ms
# Speed: 2.6ms preprocess, 62.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.148 meters
# Mode:  distance
# Distance: 1.288 meters
#
# 0: 384x640 2 persons, 49.5ms
# Speed: 1.6ms preprocess, 49.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.15 meters
# Mode:  distance
# Distance: 1.28 meters
#
# 0: 384x640 2 persons, 59.7ms
# Speed: 1.9ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.153 meters
# Mode:  distance
# Distance: 1.253 meters
#
# 0: 384x640 2 persons, 56.2ms
# Speed: 1.8ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.155 meters
# Mode:  distance
# Distance: 1.231 meters
#
# 0: 384x640 2 persons, 56.2ms
# Speed: 1.6ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.159 meters
# Mode:  distance
# Distance: 1.21 meters
#
# 0: 384x640 2 persons, 48.3ms
# Speed: 2.2ms preprocess, 48.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.161 meters
# Mode:  distance
# Distance: 1.174 meters
#
# 0: 384x640 2 persons, 48.8ms
# Speed: 1.4ms preprocess, 48.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.164 meters
# Mode:  distance
# Distance: 1.139 meters
#
# 0: 384x640 2 persons, 54.9ms
# Speed: 2.2ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.165 meters
# Mode:  distance
# Distance: 1.096 meters
#
# 0: 384x640 2 persons, 63.3ms
# Speed: 1.7ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.066 meters
# Mode:  distance
# Distance: 1.168 meters
#
# 0: 384x640 2 persons, 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.169 meters
# Mode:  distance
# Distance: 1.015 meters
#
# 0: 384x640 2 persons, 68.2ms
# Speed: 2.0ms preprocess, 68.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.968 meters
# Mode:  distance
# Distance: 1.168 meters
#
# 0: 384x640 2 persons, 66.2ms
# Speed: 2.3ms preprocess, 66.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.945 meters
# Mode:  distance
# Distance: 1.168 meters
#
# 0: 384x640 2 persons, 74.3ms
# Speed: 2.1ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.173 meters
# Mode:  distance
# Distance: 0.91 meters
#
# 0: 384x640 2 persons, 70.1ms
# Speed: 2.0ms preprocess, 70.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.179 meters
# Mode:  distance
# Distance: 0.759 meters
#
# 0: 384x640 2 persons, 64.6ms
# Speed: 2.2ms preprocess, 64.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.18 meters
# Mode:  distance
# Distance: 0.854 meters
#
# 0: 384x640 2 persons, 69.2ms
# Speed: 1.7ms preprocess, 69.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.238 meters
# Mode:  distance
# Distance: 0.747 meters
#
# 0: 384x640 3 persons, 68.5ms
# Speed: 2.1ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.743 meters
# Mode:  distance
# Distance: 1.281 meters
# Mode:  distance
# Distance: 1.3 meters
#
# 0: 384x640 2 persons, 66.5ms
# Speed: 2.6ms preprocess, 66.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.693 meters
# Mode:  distance
# Distance: 1.331 meters
#
# 0: 384x640 3 persons, 66.7ms
# Speed: 2.2ms preprocess, 66.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.617 meters
# Mode:  distance
# Distance: 1.373 meters
# Mode:  distance
# Distance: 1.294 meters
#
# 0: 384x640 3 persons, 70.1ms
# Speed: 1.9ms preprocess, 70.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.518 meters
# Mode:  distance
# Distance: 1.414 meters
# Mode:  distance
# Distance: 1.444 meters
#
# 0: 384x640 3 persons, 69.8ms
# Speed: 2.2ms preprocess, 69.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.474 meters
# Mode:  distance
# Distance: 1.486 meters
# Mode:  distance
# Distance: 0.681 meters
#
# 0: 384x640 4 persons, 68.7ms
# Speed: 1.7ms preprocess, 68.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.714 meters
# Mode:  distance
# Distance: 1.55 meters
# Mode:  distance
# Distance: 0.47 meters
# Mode:  distance
# Distance: 0.854 meters
#
# 0: 384x640 5 persons, 68.7ms
# Speed: 2.2ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.708 meters
# Mode:  distance
# Distance: 0.874 meters
# Mode:  distance
# Distance: 1.593 meters
# Mode:  distance
# Distance: 1.45 meters
# Mode:  distance
# Distance: 0.446 meters
#
# 0: 384x640 5 persons, 70.6ms
# Speed: 1.8ms preprocess, 70.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.698 meters
# Mode:  distance
# Distance: 1.627 meters
# Mode:  distance
# Distance: 0.878 meters
# Mode:  distance
# Distance: 0.442 meters
# Mode:  distance
# Distance: 1.44 meters
#
# 0: 384x640 4 persons, 74.2ms
# Speed: 2.5ms preprocess, 74.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.427 meters
# Mode:  distance
# Distance: 0.687 meters
# Mode:  distance
# Distance: 1.623 meters
# Mode:  distance
# Distance: 0.877 meters
#
# 0: 384x640 4 persons, 72.8ms
# Speed: 2.1ms preprocess, 72.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.429 meters
# Mode:  distance
# Distance: 0.695 meters
# Mode:  distance
# Distance: 1.636 meters
# Mode:  distance
# Distance: 0.904 meters
#
# 0: 384x640 4 persons, 74.0ms
# Speed: 2.1ms preprocess, 74.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.425 meters
# Mode:  distance
# Distance: 0.665 meters
# Mode:  distance
# Distance: 1.644 meters
# Mode:  distance
# Distance: 0.887 meters
#
# 0: 384x640 4 persons, 70.1ms
# Speed: 1.8ms preprocess, 70.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.437 meters
# Mode:  distance
# Distance: 0.657 meters
# Mode:  distance
# Distance: 1.676 meters
# Mode:  distance
# Distance: 1.56 meters
#
# 0: 384x640 3 persons, 71.2ms
# Speed: 1.9ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.434 meters
# Mode:  distance
# Distance: 1.687 meters
# Mode:  distance
# Distance: 1.674 meters
#
# 0: 384x640 3 persons, 67.4ms
# Speed: 2.1ms preprocess, 67.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.431 meters
# Mode:  distance
# Distance: 1.7 meters
# Mode:  distance
# Distance: 1.676 meters
#
# 0: 384x640 3 persons, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.428 meters
# Mode:  distance
# Distance: 1.686 meters
# Mode:  distance
# Distance: 1.645 meters
#
# 0: 384x640 4 persons, 74.6ms
# Speed: 1.8ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.427 meters
# Mode:  distance
# Distance: 0.621 meters
# Mode:  distance
# Distance: 1.687 meters
# Mode:  distance
# Distance: 0.997 meters
#
# 0: 384x640 4 persons, 71.6ms
# Speed: 2.2ms preprocess, 71.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.429 meters
# Mode:  distance
# Distance: 0.617 meters
# Mode:  distance
# Distance: 1.676 meters
# Mode:  distance
# Distance: 1.075 meters
#
# 0: 384x640 4 persons, 77.6ms
# Speed: 4.6ms preprocess, 77.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.613 meters
# Mode:  distance
# Distance: 0.426 meters
# Mode:  distance
# Distance: 1.637 meters
# Mode:  distance
# Distance: 1.034 meters
#
# 0: 384x640 3 persons, 76.5ms
# Speed: 2.2ms preprocess, 76.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.428 meters
# Mode:  distance
# Distance: 1.657 meters
# Mode:  distance
# Distance: 0.632 meters
#
# 0: 384x640 3 persons, 69.6ms
# Speed: 2.2ms preprocess, 69.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.425 meters
# Mode:  distance
# Distance: 0.606 meters
# Mode:  distance
# Distance: 1.677 meters
#
# 0: 384x640 2 persons, 67.2ms
# Speed: 1.9ms preprocess, 67.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.427 meters
# Mode:  distance
# Distance: 1.7 meters
#
# 0: 384x640 2 persons, 126.8ms
# Speed: 1.7ms preprocess, 126.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.426 meters
# Mode:  distance
# Distance: 1.698 meters
#
# 0: 384x640 4 persons, 70.2ms
# Speed: 8.2ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.606 meters
# Mode:  distance
# Distance: 1.689 meters
# Mode:  distance
# Distance: 1.094 meters
# Mode:  distance
# Distance: 1.643 meters
#
# 0: 384x640 5 persons, 66.8ms
# Speed: 2.1ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.433 meters
# Mode:  distance
# Distance: 0.619 meters
# Mode:  distance
# Distance: 1.711 meters
# Mode:  distance
# Distance: 1.087 meters
# Mode:  distance
# Distance: 1.65 meters
#
# 0: 384x640 5 persons, 68.6ms
# Speed: 2.2ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 0.627 meters
# Mode:  distance
# Distance: 0.429 meters
# Mode:  distance
# Distance: 1.711 meters
# Mode:  distance
# Distance: 1.657 meters
# Mode:  distance
# Distance: 1.019 meters
# WARNING ⚠️ 'source' is missing. Using 'source=/home/fcanof/.local/lib/python3.10/site-packages/ultralytics/assets'.
#
# image 1/2 /home/fcanof/.local/lib/python3.10/site-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 86.1ms
# image 2/2 /home/fcanof/.local/lib/python3.10/site-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 67.0ms
# Speed: 2.6ms preprocess, 76.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Distance: 1.804 meters
# Mode:  distance
# Distance: 2.531 meters
# Mode:  distance
# Distance: 2.875 meters
# Mode:  distance
# Distance: 5.633 meters
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[80], line 31
#      28         text = "Distance "+str(distance)+" meters"
#      29         cv2.putText(frame, text, (x+10,y+20), cv2.FONT_HERSHEY_SIMPLEX, 0.48, (255,255,255), 2)
# ---> 31 cv2.imshow('frame',frame)
#      32 count += 1
#      33 if count == 100:
#
# error: OpenCV(4.6.0) /io/opencv/modules/highgui/src/window.cpp:967: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
