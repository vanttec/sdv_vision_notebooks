# %% [markdown]
# # Pruebas Object Detection

# %%
import cv2
import numpy as np
import math
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

from pydantic import BaseModel
from collections import defaultdict

# %% [markdown]
# ## VisionEye View With Distance Calculation
# Source: https://docs.ultralytics.com/guides/vision-eye/#samples

# %%
# img = cv2.imread('bus.jpg')
model = YOLO('yolov8n.pt')
model = YOLO('yolov8n-pose.pt')
names = model.names
person_clss  = 0
print(names[person_clss])
# Out:
# person

# %%
cap = cv2.VideoCapture("personas.mp4")

w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

print(f"Video frame width: {w}, height: {h}, fps: {fps}")
# out = cv2.VideoWriter('visioneye-distance-calculation.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))

center_point = (0, h)
pixel_per_meter = 10

txt_color, txt_background, bbox_clr = ((0, 0, 0), (255, 255, 255), (255, 0, 255))

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    annotator = Annotator(im0, line_width=2)

    results = model.track(im0, persist=True)
    results.plot()
    boxes = results[0].boxes.xyxy.cpu()


    if results[0].boxes.id is not None:
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for box, track_id in zip(boxes, track_ids):
            annotator.box_label(box, label=str(track_id), color=bbox_clr)
            annotator.visioneye(box, center_point)

            x1, y1 = int((box[0] + box[2]) // 2), int((box[1] + box[3]) // 2)    # Bounding box centroid

            distance = (math.sqrt((x1 - center_point[0]) ** 2 + (y1 - center_point[1]) ** 2))/pixel_per_meter

            text_size, _ = cv2.getTextSize(f"Distance: {distance:.2f} m", cv2.FONT_HERSHEY_SIMPLEX,1.2, 3)
            cv2.rectangle(im0, (x1, y1 - text_size[1] - 10),(x1 + text_size[0] + 10, y1), txt_background, -1)
            cv2.putText(im0, f"Distance: {distance:.2f} m",(x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 1.2,txt_color, 3)

    # out.write(im0)
    cv2.imshow("visioneye-distance-calculation", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# Video frame width: 0, height: 0, fps: 0
# Video frame is empty or video processing has been successfully completed.

# %% [markdown]
# ## Distance Calculation
#
# Source:
# * https://github.com/Asadullah-Dal17/Yolov4-Detector-and-Distance-Estimator/blob/master/DistanceEstimation.py
# * https://www.youtube.com/watch?v=FcRCwTgYXJw&ab_channel=AiPhile

# %% [markdown]
# ### Funciones Auxiliares

# %%
def focal_length_finder(measured_distance, real_width, width_in_frame):
    focal_length = (width_in_frame * measured_distance) / real_width
    return focal_length

# %%
def distance_finder(focal_length, real_width, width_in_frame):
    distance = (real_width * focal_length) / width_in_frame
    return distance

# %% [markdown]
# ### Detección y Calculo de distancia en Video

# %%
# Medidas en metros
KNOWN_DISTANCE = 2
PERSON_WIDTH = 0.38 # Ancho de una persona promedio - Medidas de Fri - 38 cm
VIDEO_PATH = "//home/fcanof/Documents/sdv_vision_notebooks/data/ref_video/2_personas.mp4"

# %% [markdown]
# Con Bounding Boxes / Impreciso

# %%
cap = cv2.VideoCapture(VIDEO_PATH)
count = 0
while True:
    ret, frame = cap.read()

    results = model(frame, classes=0)
    if results[0].boxes is not None:
        boxes_w = results[0].boxes.xywh.cpu()
        boxes_xyxy = results[0].boxes.xyxy.cpu()
        for box_w, box_xyxy in zip(boxes_w, boxes_xyxy):
            print("Mode: ", MODE)
            person_width = box_w[2]
            person_height = box_w[3]
            x,y = int(box_xyxy[0]), int(box_xyxy[1]+(person_height-50))
            if MODE == "calibration":
                focal_person = focal_length_finder(KNOWN_DISTANCE, PERSON_WIDTH, person_width)
                print(f"Focal length: {focal_person}")
            else:
                distance = distance_finder(focal_person, PERSON_WIDTH, person_width)
                distance = round(float(distance), 3)
                print(f"Distance: {distance} meters")
            cv2.rectangle(frame, (x, y-1), (x+200, y+25), (0,0,255),-1 )
            text = "Distance "+str(distance)+" meters"
            cv2.putText(frame, text, (x+10,y+20), cv2.FONT_HERSHEY_SIMPLEX, 0.48, (255,255,255), 2)

    cv2.imshow('frame',frame)
    count += 1
    if count == 100:
        MODE = "distance"
    key = cv2.waitKey(1)
    if key ==ord('q'):
        break
cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# Con KeyPoints / Más Preciso

# %%
class GetKeypoint(BaseModel):
    NOSE:           int = 0
    LEFT_EYE:       int = 1
    RIGHT_EYE:      int = 2
    LEFT_EAR:       int = 3
    RIGHT_EAR:      int = 4
    LEFT_SHOULDER:  int = 5
    RIGHT_SHOULDER: int = 6
    LEFT_ELBOW:     int = 7
    RIGHT_ELBOW:    int = 8
    LEFT_WRIST:     int = 9
    RIGHT_WRIST:    int = 10
    LEFT_HIP:       int = 11
    RIGHT_HIP:      int = 12
    LEFT_KNEE:      int = 13
    RIGHT_KNEE:     int = 14
    LEFT_ANKLE:     int = 15
    RIGHT_ANKLE:    int = 16
get_keypoint = GetKeypoint()
cap = cv2.VideoCapture(VIDEO_PATH)
count = 0
MODE = "calibration"
while True:
    ret, frame = cap.read()

    results = model(frame, classes=0, show=True, conf = 0.8)
    if results[0].boxes is not None:
        boxes_w = results[0].boxes.xywh.cpu()
        boxes_xyxy = results[0].boxes.xyxy.cpu()
        keypoints = results[0].keypoints.xy.cpu().numpy()
        for box_w, box_xyxy, keypoint in zip(boxes_w, boxes_xyxy, keypoints):
            print("Mode: ", MODE)
            shoulder_left_x, _sly = keypoint[get_keypoint.LEFT_SHOULDER]
            shoulder_right_x, _sry = keypoint[get_keypoint.RIGHT_SHOULDER]
            person_width = int(abs(shoulder_left_x - shoulder_right_x))
            print("Person width: ", person_width)
            person_height = box_w[3]
            x,y = int(box_xyxy[0]), int(box_xyxy[1]+(person_height-50))
            if MODE == "calibration":
                focal_person = focal_length_finder(KNOWN_DISTANCE, PERSON_WIDTH, person_width)
                print(f"Focal length: {focal_person}")
            else:
                distance = distance_finder(focal_person, PERSON_WIDTH, person_width)
                distance = round(float(distance), 3)
                print(f"Distance: {distance} meters")
            cv2.rectangle(frame, (x, y-1), (x+200, y+25), (0,0,255),-1 )
            text = "Distance "+str(distance)+" meters"
            cv2.putText(frame, text, (x+10,y+20), cv2.FONT_HERSHEY_SIMPLEX, 0.48, (255,255,255), 2)

    cv2.imshow('frame',frame)
    count += 1
    if count == 150:
        MODE = "distance"
    key = cv2.waitKey(1)
    if key ==ord('q'):
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# 0: 384x640 1 person, 90.2ms
# Speed: 3.3ms preprocess, 90.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 88.0ms
# Speed: 3.6ms preprocess, 88.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 80.5ms
# Speed: 2.9ms preprocess, 80.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 84.2ms
# Speed: 6.4ms preprocess, 84.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 70.3ms
# Speed: 1.5ms preprocess, 70.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 81.9ms
# Speed: 2.1ms preprocess, 81.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 77.3ms
# Speed: 2.6ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 76.0ms
# Speed: 2.9ms preprocess, 76.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 84.4ms
# Speed: 3.1ms preprocess, 84.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  296
# Focal length: 1557.8947368421052
#
# 0: 384x640 1 person, 74.2ms
# Speed: 1.9ms preprocess, 74.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 67.9ms
# Speed: 2.4ms preprocess, 67.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 79.3ms
# Speed: 2.0ms preprocess, 79.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 64.4ms
# Speed: 1.7ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 62.3ms
# Speed: 1.9ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 67.0ms
# Speed: 1.7ms preprocess, 67.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 65.2ms
# Speed: 1.7ms preprocess, 65.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 69.1ms
# Speed: 2.0ms preprocess, 69.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  266
# Focal length: 1400.0
#
# 0: 384x640 1 person, 68.7ms
# Speed: 2.1ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  277
# Focal length: 1457.8947368421052
#
# 0: 384x640 1 person, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  276
# Focal length: 1452.6315789473683
#
# 0: 384x640 1 person, 65.5ms
# Speed: 1.8ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  242
# Focal length: 1273.6842105263158
#
# 0: 384x640 1 person, 66.9ms
# Speed: 1.8ms preprocess, 66.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 78.9ms
# Speed: 2.6ms preprocess, 78.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  0
# Focal length: 0.0
#
# 0: 384x640 1 person, 78.6ms
# Speed: 2.0ms preprocess, 78.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  287
# Focal length: 1510.5263157894738
#
# 0: 384x640 1 person, 76.9ms
# Speed: 3.1ms preprocess, 76.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  218
# Focal length: 1147.3684210526317
#
# 0: 384x640 1 person, 84.0ms
# Speed: 2.3ms preprocess, 84.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  212
# Focal length: 1115.7894736842104
#
# 0: 384x640 1 person, 86.2ms
# Speed: 2.5ms preprocess, 86.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  201
# Focal length: 1057.8947368421052
#
# 0: 384x640 1 person, 74.4ms
# Speed: 3.4ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  187
# Focal length: 984.2105263157895
#
# 0: 384x640 1 person, 68.2ms
# Speed: 1.6ms preprocess, 68.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  174
# Focal length: 915.7894736842105
#
# 0: 384x640 1 person, 66.0ms
# Speed: 1.8ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  178
# Focal length: 936.8421052631579
#
# 0: 384x640 1 person, 77.2ms
# Speed: 2.1ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  168
# Focal length: 884.2105263157895
#
# 0: 384x640 1 person, 63.3ms
# Speed: 1.9ms preprocess, 63.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  161
# Focal length: 847.3684210526316
#
# 0: 384x640 1 person, 69.0ms
# Speed: 1.7ms preprocess, 69.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  152
# Focal length: 800.0
#
# 0: 384x640 1 person, 73.3ms
# Speed: 1.8ms preprocess, 73.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  148
# Focal length: 778.9473684210526
#
# 0: 384x640 1 person, 80.6ms
# Speed: 2.2ms preprocess, 80.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  146
# Focal length: 768.421052631579
#
# 0: 384x640 1 person, 72.7ms
# Speed: 1.9ms preprocess, 72.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  143
# Focal length: 752.6315789473684
#
# 0: 384x640 1 person, 68.8ms
# Speed: 1.7ms preprocess, 68.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  141
# Focal length: 742.1052631578947
#
# 0: 384x640 1 person, 66.3ms
# Speed: 1.5ms preprocess, 66.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  134
# Focal length: 705.2631578947369
#
# 0: 384x640 1 person, 62.4ms
# Speed: 1.8ms preprocess, 62.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  131
# Focal length: 689.4736842105264
#
# 0: 384x640 1 person, 80.5ms
# Speed: 1.9ms preprocess, 80.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  135
# Focal length: 710.5263157894736
#
# 0: 384x640 1 person, 76.8ms
# Speed: 1.7ms preprocess, 76.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  130
# Focal length: 684.2105263157895
#
# 0: 384x640 1 person, 82.0ms
# Speed: 2.4ms preprocess, 82.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  126
# Focal length: 663.1578947368421
#
# 0: 384x640 1 person, 76.1ms
# Speed: 1.9ms preprocess, 76.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  121
# Focal length: 636.8421052631579
#
# 0: 384x640 1 person, 78.2ms
# Speed: 1.9ms preprocess, 78.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  115
# Focal length: 605.2631578947369
#
# 0: 384x640 1 person, 92.3ms
# Speed: 2.2ms preprocess, 92.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  109
# Focal length: 573.6842105263158
#
# 0: 384x640 1 person, 109.0ms
# Speed: 4.6ms preprocess, 109.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  106
# Focal length: 557.8947368421052
#
# 0: 384x640 1 person, 101.3ms
# Speed: 3.7ms preprocess, 101.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  96
# Focal length: 505.2631578947368
#
# 0: 384x640 1 person, 167.8ms
# Speed: 2.3ms preprocess, 167.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  92
# Focal length: 484.2105263157895
#
# 0: 384x640 1 person, 89.8ms
# Speed: 2.8ms preprocess, 89.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  87
# Focal length: 457.89473684210526
#
# 0: 384x640 1 person, 84.4ms
# Speed: 2.5ms preprocess, 84.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  81
# Focal length: 426.3157894736842
#
# 0: 384x640 1 person, 80.3ms
# Speed: 2.2ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  77
# Focal length: 405.2631578947368
#
# 0: 384x640 1 person, 79.7ms
# Speed: 2.2ms preprocess, 79.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  67
# Focal length: 352.63157894736844
#
# 0: 384x640 1 person, 77.1ms
# Speed: 2.6ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  64
# Focal length: 336.8421052631579
#
# 0: 384x640 1 person, 78.7ms
# Speed: 1.9ms preprocess, 78.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  59
# Focal length: 310.5263157894737
#
# 0: 384x640 1 person, 83.1ms
# Speed: 2.0ms preprocess, 83.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  56
# Focal length: 294.7368421052632
#
# 0: 384x640 1 person, 92.9ms
# Speed: 2.0ms preprocess, 92.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  54
# Focal length: 284.2105263157895
#
# 0: 384x640 1 person, 125.7ms
# Speed: 11.6ms preprocess, 125.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  51
# Focal length: 268.42105263157896
#
# 0: 384x640 1 person, 107.5ms
# Speed: 3.4ms preprocess, 107.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  45
# Focal length: 236.8421052631579
#
# 0: 384x640 1 person, 93.0ms
# Speed: 2.9ms preprocess, 93.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  42
# Focal length: 221.05263157894737
#
# 0: 384x640 1 person, 92.7ms
# Speed: 1.9ms preprocess, 92.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  42
# Focal length: 221.05263157894737
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.3ms preprocess, 99.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  43
# Focal length: 226.31578947368422
#
# 0: 384x640 1 person, 90.1ms
# Speed: 2.3ms preprocess, 90.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  42
# Focal length: 221.05263157894737
#
# 0: 384x640 1 person, 90.8ms
# Speed: 1.8ms preprocess, 90.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  42
# Focal length: 221.05263157894737
#
# 0: 384x640 1 person, 111.8ms
# Speed: 2.9ms preprocess, 111.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  45
# Focal length: 236.8421052631579
#
# 0: 384x640 1 person, 97.1ms
# Speed: 3.2ms preprocess, 97.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  57
# Focal length: 300.0
#
# 0: 384x640 1 person, 81.5ms
# Speed: 2.5ms preprocess, 81.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  56
# Focal length: 294.7368421052632
#
# 0: 384x640 1 person, 84.3ms
# Speed: 2.2ms preprocess, 84.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  51
# Focal length: 268.42105263157896
#
# 0: 384x640 1 person, 85.4ms
# Speed: 2.2ms preprocess, 85.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  59
# Focal length: 310.5263157894737
#
# 0: 384x640 1 person, 85.0ms
# Speed: 2.7ms preprocess, 85.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  64
# Focal length: 336.8421052631579
#
# 0: 384x640 1 person, 79.8ms
# Speed: 2.3ms preprocess, 79.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  55
# Focal length: 289.4736842105263
#
# 0: 384x640 1 person, 79.2ms
# Speed: 2.4ms preprocess, 79.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  63
# Focal length: 331.57894736842104
#
# 0: 384x640 1 person, 76.6ms
# Speed: 2.2ms preprocess, 76.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  62
# Focal length: 326.3157894736842
#
# 0: 384x640 1 person, 87.4ms
# Speed: 2.0ms preprocess, 87.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  67
# Focal length: 352.63157894736844
#
# 0: 384x640 1 person, 95.8ms
# Speed: 2.0ms preprocess, 95.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  72
# Focal length: 378.9473684210526
#
# 0: 384x640 1 person, 93.2ms
# Speed: 2.6ms preprocess, 93.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.6ms preprocess, 101.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 100.5ms
# Speed: 2.7ms preprocess, 100.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 88.4ms
# Speed: 2.2ms preprocess, 88.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 98.5ms
# Speed: 3.0ms preprocess, 98.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  71
# Focal length: 373.6842105263158
#
# 0: 384x640 1 person, 101.3ms
# Speed: 3.1ms preprocess, 101.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 95.2ms
# Speed: 3.1ms preprocess, 95.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  76
# Focal length: 400.0
#
# 0: 384x640 1 person, 76.2ms
# Speed: 2.1ms preprocess, 76.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  75
# Focal length: 394.7368421052632
#
# 0: 384x640 1 person, 75.6ms
# Speed: 2.3ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  75
# Focal length: 394.7368421052632
#
# 0: 384x640 1 person, 65.5ms
# Speed: 1.9ms preprocess, 65.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  75
# Focal length: 394.7368421052632
#
# 0: 384x640 1 person, 62.5ms
# Speed: 1.8ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 68.5ms
# Speed: 1.7ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 69.0ms
# Speed: 1.7ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 64.0ms
# Speed: 2.1ms preprocess, 64.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 65.7ms
# Speed: 1.7ms preprocess, 65.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 73.4ms
# Speed: 2.1ms preprocess, 73.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  75
# Focal length: 394.7368421052632
#
# 0: 384x640 1 person, 85.0ms
# Speed: 2.3ms preprocess, 85.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  75
# Focal length: 394.7368421052632
#
# 0: 384x640 1 person, 85.9ms
# Speed: 3.0ms preprocess, 85.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 77.3ms
# Speed: 3.3ms preprocess, 77.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 70.2ms
# Speed: 2.1ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 66.0ms
# Speed: 1.9ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 63.5ms
# Speed: 1.8ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 67.0ms
# Speed: 1.6ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 65.2ms
# Speed: 1.6ms preprocess, 65.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 64.7ms
# Speed: 1.8ms preprocess, 64.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 66.6ms
# Speed: 1.5ms preprocess, 66.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  72
# Focal length: 378.9473684210526
#
# 0: 384x640 1 person, 67.3ms
# Speed: 1.8ms preprocess, 67.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  72
# Focal length: 378.9473684210526
#
# 0: 384x640 1 person, 58.1ms
# Speed: 1.6ms preprocess, 58.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 66.9ms
# Speed: 1.7ms preprocess, 66.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 66.3ms
# Speed: 1.9ms preprocess, 66.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 59.5ms
# Speed: 1.8ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 59.8ms
# Speed: 1.8ms preprocess, 59.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 61.3ms
# Speed: 1.8ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  72
# Focal length: 378.9473684210526
#
# 0: 384x640 1 person, 67.6ms
# Speed: 2.0ms preprocess, 67.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 66.1ms
# Speed: 2.2ms preprocess, 66.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 66.2ms
# Speed: 1.7ms preprocess, 66.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  73
# Focal length: 384.2105263157895
#
# 0: 384x640 1 person, 61.0ms
# Speed: 1.5ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  74
# Focal length: 389.4736842105263
#
# 0: 384x640 1 person, 57.5ms
# Speed: 1.5ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  75
# Focal length: 394.7368421052632
#
# 0: 384x640 1 person, 57.5ms
# Speed: 1.8ms preprocess, 57.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  76
# Focal length: 400.0
#
# 0: 384x640 1 person, 62.4ms
# Speed: 1.9ms preprocess, 62.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  77
# Focal length: 405.2631578947368
#
# 0: 384x640 1 person, 65.9ms
# Speed: 1.5ms preprocess, 65.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  78
# Focal length: 410.5263157894737
#
# 0: 384x640 1 person, 68.5ms
# Speed: 1.4ms preprocess, 68.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  78
# Focal length: 410.5263157894737
#
# 0: 384x640 1 person, 66.1ms
# Speed: 1.4ms preprocess, 66.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  78
# Focal length: 410.5263157894737
#
# 0: 384x640 1 person, 67.4ms
# Speed: 1.8ms preprocess, 67.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  78
# Focal length: 410.5263157894737
#
# 0: 384x640 1 person, 66.9ms
# Speed: 1.4ms preprocess, 66.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  78
# Focal length: 410.5263157894737
#
# 0: 384x640 1 person, 66.0ms
# Speed: 1.6ms preprocess, 66.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  78
# Focal length: 410.5263157894737
#
# 0: 384x640 1 person, 64.1ms
# Speed: 1.5ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  78
# Focal length: 410.5263157894737
#
# 0: 384x640 1 person, 60.7ms
# Speed: 1.7ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  78
# Focal length: 410.5263157894737
#
# 0: 384x640 1 person, 61.3ms
# Speed: 1.9ms preprocess, 61.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 64.1ms
# Speed: 1.7ms preprocess, 64.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 62.5ms
# Speed: 1.7ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 66.1ms
# Speed: 1.4ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 67.9ms
# Speed: 1.5ms preprocess, 67.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 65.6ms
# Speed: 1.8ms preprocess, 65.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 69.7ms
# Speed: 1.7ms preprocess, 69.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 61.3ms
# Speed: 2.1ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 64.6ms
# Speed: 1.8ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 64.8ms
# Speed: 1.9ms preprocess, 64.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 66.0ms
# Speed: 1.7ms preprocess, 66.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 108.5ms
# Speed: 2.7ms preprocess, 108.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 69.1ms
# Speed: 2.0ms preprocess, 69.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 60.9ms
# Speed: 1.6ms preprocess, 60.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 60.8ms
# Speed: 1.9ms preprocess, 60.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  79
# Focal length: 415.7894736842105
#
# 0: 384x640 1 person, 73.8ms
# Speed: 1.7ms preprocess, 73.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  80
# Focal length: 421.05263157894734
#
# 0: 384x640 1 person, 66.6ms
# Speed: 2.2ms preprocess, 66.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  80
# Focal length: 421.05263157894734
#
# 0: 384x640 1 person, 76.6ms
# Speed: 1.9ms preprocess, 76.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  80
# Focal length: 421.05263157894734
#
# 0: 384x640 1 person, 79.7ms
# Speed: 1.9ms preprocess, 79.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  80
# Focal length: 421.05263157894734
#
# 0: 384x640 1 person, 74.5ms
# Speed: 2.2ms preprocess, 74.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  80
# Focal length: 421.05263157894734
#
# 0: 384x640 1 person, 78.5ms
# Speed: 1.6ms preprocess, 78.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  80
# Focal length: 421.05263157894734
#
# 0: 384x640 1 person, 78.8ms
# Speed: 2.1ms preprocess, 78.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  81
# Focal length: 426.3157894736842
#
# 0: 384x640 1 person, 78.4ms
# Speed: 1.9ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  80
# Focal length: 421.05263157894734
#
# 0: 384x640 1 person, 77.0ms
# Speed: 1.9ms preprocess, 77.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  calibration
# Person width:  80
# Focal length: 421.05263157894734
#
# 0: 384x640 1 person, 76.0ms
# Speed: 2.1ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  80
# Distance: 2.0 meters
#
# 0: 384x640 1 person, 77.4ms
# Speed: 2.1ms preprocess, 77.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  80
# Distance: 2.0 meters
#
# 0: 384x640 1 person, 73.8ms
# Speed: 2.8ms preprocess, 73.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 75.3ms
# Speed: 1.9ms preprocess, 75.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 77.1ms
# Speed: 2.2ms preprocess, 77.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 75.2ms
# Speed: 2.1ms preprocess, 75.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 68.9ms
# Speed: 2.3ms preprocess, 68.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 78.6ms
# Speed: 2.7ms preprocess, 78.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 77.1ms
# Speed: 2.2ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  83
# Distance: 1.928 meters
#
# 0: 384x640 1 person, 78.4ms
# Speed: 2.2ms preprocess, 78.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 78.5ms
# Speed: 2.0ms preprocess, 78.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 73.7ms
# Speed: 2.3ms preprocess, 73.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  83
# Distance: 1.928 meters
#
# 0: 384x640 1 person, 83.4ms
# Speed: 2.2ms preprocess, 83.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  83
# Distance: 1.928 meters
#
# 0: 384x640 1 person, 73.3ms
# Speed: 2.7ms preprocess, 73.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  83
# Distance: 1.928 meters
#
# 0: 384x640 1 person, 78.2ms
# Speed: 1.9ms preprocess, 78.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  83
# Distance: 1.928 meters
#
# 0: 384x640 1 person, 78.5ms
# Speed: 1.7ms preprocess, 78.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 76.1ms
# Speed: 1.6ms preprocess, 76.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 73.4ms
# Speed: 1.8ms preprocess, 73.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 68.4ms
# Speed: 2.3ms preprocess, 68.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 72.5ms
# Speed: 1.6ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 76.1ms
# Speed: 1.5ms preprocess, 76.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 72.3ms
# Speed: 2.0ms preprocess, 72.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 74.5ms
# Speed: 1.9ms preprocess, 74.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 66.4ms
# Speed: 2.5ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 66.8ms
# Speed: 2.3ms preprocess, 66.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 71.0ms
# Speed: 1.9ms preprocess, 71.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 71.8ms
# Speed: 1.8ms preprocess, 71.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 74.1ms
# Speed: 1.9ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 71.2ms
# Speed: 2.0ms preprocess, 71.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 68.6ms
# Speed: 2.7ms preprocess, 68.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 67.7ms
# Speed: 1.8ms preprocess, 67.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 72.1ms
# Speed: 1.8ms preprocess, 72.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 70.8ms
# Speed: 2.3ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 72.4ms
# Speed: 2.0ms preprocess, 72.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 75.0ms
# Speed: 1.5ms preprocess, 75.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 69.2ms
# Speed: 2.6ms preprocess, 69.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 67.2ms
# Speed: 1.7ms preprocess, 67.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 83.4ms
# Speed: 2.5ms preprocess, 83.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 86.6ms
# Speed: 9.4ms preprocess, 86.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 67.5ms
# Speed: 2.6ms preprocess, 67.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 63.6ms
# Speed: 2.3ms preprocess, 63.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 64.4ms
# Speed: 2.4ms preprocess, 64.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 60.9ms
# Speed: 1.8ms preprocess, 60.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 61.0ms
# Speed: 1.5ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 65.1ms
# Speed: 1.7ms preprocess, 65.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 62.8ms
# Speed: 1.6ms preprocess, 62.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 62.2ms
# Speed: 1.9ms preprocess, 62.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 58.6ms
# Speed: 1.8ms preprocess, 58.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 59.2ms
# Speed: 1.4ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 57.8ms
# Speed: 2.4ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 67.4ms
# Speed: 2.0ms preprocess, 67.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 71.9ms
# Speed: 1.8ms preprocess, 71.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 56.7ms
# Speed: 1.5ms preprocess, 56.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 55.9ms
# Speed: 1.6ms preprocess, 55.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  83
# Distance: 1.928 meters
#
# 0: 384x640 1 person, 53.4ms
# Speed: 1.6ms preprocess, 53.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  83
# Distance: 1.928 meters
#
# 0: 384x640 1 person, 54.9ms
# Speed: 2.1ms preprocess, 54.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  84
# Distance: 1.905 meters
#
# 0: 384x640 1 person, 53.6ms
# Speed: 1.6ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  84
# Distance: 1.905 meters
#
# 0: 384x640 1 person, 55.8ms
# Speed: 1.8ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 64.4ms
# Speed: 2.2ms preprocess, 64.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 62.5ms
# Speed: 2.5ms preprocess, 62.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 62.8ms
# Speed: 1.5ms preprocess, 62.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  87
# Distance: 1.839 meters
#
# 0: 384x640 1 person, 65.1ms
# Speed: 2.3ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  87
# Distance: 1.839 meters
#
# 0: 384x640 1 person, 62.1ms
# Speed: 2.2ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  88
# Distance: 1.818 meters
#
# 0: 384x640 1 person, 61.2ms
# Speed: 1.6ms preprocess, 61.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  89
# Distance: 1.798 meters
#
# 0: 384x640 1 person, 60.8ms
# Speed: 1.7ms preprocess, 60.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  87
# Distance: 1.839 meters
#
# 0: 384x640 1 person, 60.5ms
# Speed: 1.7ms preprocess, 60.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  88
# Distance: 1.818 meters
#
# 0: 384x640 1 person, 65.6ms
# Speed: 1.5ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  87
# Distance: 1.839 meters
#
# 0: 384x640 1 person, 60.8ms
# Speed: 1.6ms preprocess, 60.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  87
# Distance: 1.839 meters
#
# 0: 384x640 1 person, 63.1ms
# Speed: 1.8ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  87
# Distance: 1.839 meters
#
# 0: 384x640 1 person, 56.3ms
# Speed: 1.9ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  86
# Distance: 1.86 meters
#
# 0: 384x640 1 person, 55.3ms
# Speed: 1.6ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 62.9ms
# Speed: 1.6ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 63.5ms
# Speed: 1.8ms preprocess, 63.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 66.7ms
# Speed: 1.6ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 66.5ms
# Speed: 2.1ms preprocess, 66.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 66.5ms
# Speed: 2.1ms preprocess, 66.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  86
# Distance: 1.86 meters
#
# 0: 384x640 1 person, 71.3ms
# Speed: 2.2ms preprocess, 71.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  86
# Distance: 1.86 meters
#
# 0: 384x640 1 person, 62.4ms
# Speed: 1.8ms preprocess, 62.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 56.8ms
# Speed: 1.9ms preprocess, 56.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 64.4ms
# Speed: 1.8ms preprocess, 64.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 67.4ms
# Speed: 1.7ms preprocess, 67.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 65.7ms
# Speed: 1.3ms preprocess, 65.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 65.2ms
# Speed: 2.0ms preprocess, 65.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 62.5ms
# Speed: 1.6ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  84
# Distance: 1.905 meters
#
# 0: 384x640 1 person, 63.1ms
# Speed: 1.7ms preprocess, 63.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  83
# Distance: 1.928 meters
#
# 0: 384x640 1 person, 63.0ms
# Speed: 1.6ms preprocess, 63.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  85
# Distance: 1.882 meters
#
# 0: 384x640 1 person, 63.1ms
# Speed: 1.6ms preprocess, 63.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 66.1ms
# Speed: 1.5ms preprocess, 66.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 65.5ms
# Speed: 1.8ms preprocess, 65.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 66.6ms
# Speed: 1.4ms preprocess, 66.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 66.5ms
# Speed: 1.6ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  82
# Distance: 1.951 meters
#
# 0: 384x640 1 person, 64.8ms
# Speed: 1.6ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 67.4ms
# Speed: 1.5ms preprocess, 67.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 65.6ms
# Speed: 1.8ms preprocess, 65.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  80
# Distance: 2.0 meters
#
# 0: 384x640 1 person, 62.5ms
# Speed: 1.8ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# Distance: 1.975 meters
#
# 0: 384x640 1 person, 61.5ms
# Speed: 1.3ms preprocess, 61.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  81
# ...
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  147
# Distance: 1.088 meters
#
# 0: 384x640 2 persons, 63.8ms
# Speed: 1.5ms preprocess, 63.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  148
# Distance: 1.081 meters
#
# 0: 384x640 2 persons, 68.2ms
# Speed: 1.6ms preprocess, 68.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  148
# Distance: 1.081 meters
#
# 0: 384x640 2 persons, 66.8ms
# Speed: 1.5ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  70
# Distance: 2.286 meters
# Mode:  distance
# Person width:  147
# Distance: 1.088 meters
#
# 0: 384x640 2 persons, 71.6ms
# Speed: 1.4ms preprocess, 71.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  149
# Distance: 1.074 meters
#
# 0: 384x640 2 persons, 85.1ms
# Speed: 2.6ms preprocess, 85.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  148
# Distance: 1.081 meters
#
# 0: 384x640 2 persons, 69.0ms
# Speed: 1.5ms preprocess, 69.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  151
# Distance: 1.06 meters
#
# 0: 384x640 2 persons, 71.5ms
# Speed: 1.5ms preprocess, 71.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  149
# Distance: 1.074 meters
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
#
# 0: 384x640 2 persons, 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  148
# Distance: 1.081 meters
#
# 0: 384x640 2 persons, 75.8ms
# Speed: 2.8ms preprocess, 75.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  150
# Distance: 1.067 meters
#
# 0: 384x640 2 persons, 69.7ms
# Speed: 2.3ms preprocess, 69.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  71
# Distance: 2.254 meters
# Mode:  distance
# Person width:  149
# Distance: 1.074 meters
#
# 0: 384x640 2 persons, 70.7ms
# Speed: 1.5ms preprocess, 70.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  72
# Distance: 2.222 meters
# Mode:  distance
# Person width:  150
# Distance: 1.067 meters
#
# 0: 384x640 2 persons, 74.1ms
# Speed: 1.3ms preprocess, 74.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  72
# Distance: 2.222 meters
# Mode:  distance
# Person width:  150
# Distance: 1.067 meters
#
# 0: 384x640 2 persons, 130.9ms
# Speed: 2.3ms preprocess, 130.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  150
# Distance: 1.067 meters
# Mode:  distance
# Person width:  72
# Distance: 2.222 meters
#
# 0: 384x640 2 persons, 79.1ms
# Speed: 2.1ms preprocess, 79.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  149
# Distance: 1.074 meters
# Mode:  distance
# Person width:  73
# Distance: 2.192 meters
#
# 0: 384x640 2 persons, 80.8ms
# Speed: 1.6ms preprocess, 80.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  150
# Distance: 1.067 meters
# Mode:  distance
# Person width:  73
# Distance: 2.192 meters
#
# 0: 384x640 2 persons, 70.5ms
# Speed: 1.5ms preprocess, 70.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  151
# Distance: 1.06 meters
# Mode:  distance
# Person width:  73
# Distance: 2.192 meters
#
# 0: 384x640 2 persons, 71.5ms
# Speed: 1.8ms preprocess, 71.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  149
# Distance: 1.074 meters
# Mode:  distance
# Person width:  74
# Distance: 2.162 meters
#
# 0: 384x640 2 persons, 74.1ms
# Speed: 1.4ms preprocess, 74.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  150
# Distance: 1.067 meters
# Mode:  distance
# Person width:  74
# Distance: 2.162 meters
#
# 0: 384x640 2 persons, 68.5ms
# Speed: 1.7ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  148
# Distance: 1.081 meters
# Mode:  distance
# Person width:  75
# Distance: 2.133 meters
#
# 0: 384x640 2 persons, 68.5ms
# Speed: 1.5ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  148
# Distance: 1.081 meters
# Mode:  distance
# Person width:  75
# Distance: 2.133 meters
#
# 0: 384x640 2 persons, 69.5ms
# Speed: 2.2ms preprocess, 69.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  151
# Distance: 1.06 meters
# Mode:  distance
# Person width:  77
# Distance: 2.078 meters
#
# 0: 384x640 2 persons, 75.1ms
# Speed: 1.6ms preprocess, 75.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  153
# Distance: 1.046 meters
# Mode:  distance
# Person width:  77
# Distance: 2.078 meters
#
# 0: 384x640 2 persons, 78.7ms
# Speed: 1.6ms preprocess, 78.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Mode:  distance
# Person width:  153
# Distance: 1.046 meters
# Mode:  distance
# Person width:  78
# Distance: 2.051 meters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[97], line 26
#      23 while True:
#      24     ret, frame = cap.read()
# ---> 26     results = model(frame, classes=0, show=True, conf = 0.8)
#      27     if results[0].boxes is not None:
#      28         boxes_w = results[0].boxes.xywh.cpu()
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:169, in Model.__call__(self, source, stream, **kwargs)
#     146 def __call__(
#     147     self,
#     148     source: Union[str, Path, int, list, tuple, np.ndarray, torch.Tensor] = None,
#     149     stream: bool = False,
#     150     **kwargs,
#     151 ) -> list:
#     152     """
#     153     An alias for the predict method, enabling the model instance to be callable.
#     154
#    (...)
#     167         (List[ultralytics.engine.results.Results]): A list of prediction results, encapsulated in the Results class.
#     168     """
# --> 169     return self.predict(source, stream, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:429, in Model.predict(self, source, stream, predictor, **kwargs)
#     427 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     428     self.predictor.set_prompts(prompts)
# --> 429 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:205, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     203     return self.stream_inference(source, model, *args, **kwargs)
#     204 else:
# --> 205     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:284, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     282 # Inference
#     283 with profilers[1]:
# --> 284     preds = self.inference(im, *args, **kwargs)
#     285     if self.args.embed:
#     286         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:141, in BasePredictor.inference(self, im, *args, **kwargs)
#     135 """Runs inference on a given image using the specified model and arguments."""
#     136 visualize = (
#     137     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     138     if self.args.visualize and (not self.source_type.tensor)
#     139     else False
#     140 )
# --> 141 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:384, in AutoBackend.forward(self, im, augment, visualize, embed)
#     381     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     383 if self.pt or self.nn_module:  # PyTorch
# --> 384     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     385 elif self.jit:  # TorchScript
#     386     y = self.model(im)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:83, in BaseModel.forward(self, x, *args, **kwargs)
#      81 if isinstance(x, dict):  # for cases of training and validating while training.
#      82     return self.loss(x, *args, **kwargs)
# ---> 83 return self.predict(x, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:101, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#      99 if augment:
#     100     return self._predict_augment(x)
# --> 101 return self._predict_once(x, profile, visualize, embed)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:122, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     120 if profile:
#     121     self._profile_one_layer(m, x, dt)
# --> 122 x = m(x)  # run
#     123 y.append(x if m.i in self.save else None)  # save output
#     124 if visualize:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/head.py:165, in Pose.forward(self, x)
#     163 bs = x[0].shape[0]  # batch size
#     164 kpt = torch.cat([self.cv4[i](x[i]).view(bs, self.nk, -1) for i in range(self.nl)], -1)  # (bs, 17*3, h*w)
# --> 165 x = self.detect(self, x)
#     166 if self.training:
#     167     return x, kpt
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/head.py:46, in Detect.forward(self, x)
#      44 """Concatenates and returns predicted bounding boxes and class probabilities."""
#      45 for i in range(self.nl):
# ---> 46     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      47 if self.training:  # Training path
#      48     return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1678, in Module.__getattr__(self, name)
#    1676 if '_parameters' in self.__dict__:
#    1677     _parameters = self.__dict__['_parameters']
# -> 1678     if name in _parameters:
#    1679         return _parameters[name]
#    1680 if '_buffers' in self.__dict__:
#
# KeyboardInterrupt:
